# %% [markdown]
# # 3 Capstone II Exploratory Data Analysis

# %% [markdown]
# ## The U.S. Petroleum Refinery and Market Profiles

# %% [markdown]
# We will be looking at 121+ U.S. petroleum refineries and their operating capacities in relation to the top U.S. 65 major cities by population. The relation will be measured in terms of distance from each refinery to the major cities and population size of each city, to derrive at market size in volume of petroleum products and USD values at destination market prices.

# %% [markdown]
# The first thing is, we will narrow down the analysis to the contiguous states only, that is, exclude Alaska and Hawaii, as they are outlier cases

# %% [markdown]
# # 3.1 Imports

# %%
import os
from library.sb_utils import save_file

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %% [markdown]
# # 3.2 Load The Data

# %% [markdown]
# ## 3.2.1 Profiles Data

# %%
# Load the data
data = pd.read_excel('../data/df.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 76 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Series              971 non-null    object
#  1   RFY-PADD            971 non-null    object
#  2   RFY-PAD-Sub         971 non-null    object
#  3   RFY-PAD-District    971 non-null    object
#  4   RFY_ID              971 non-null    object
#  5   RFY_State           971 non-null    object
#  6   RFY_BPCD            971 non-null    int64
#  7   CATCRKRECYL         971 non-null    int64
#  8   CATHYDRCRCK         971 non-null    int64
#  9   CATHYDTRMT          971 non-null    int64
#  10  CATLREFORM          971 non-null    int64
#  11  CATLYTCRCK          971 non-null    int64
#  12  COKING              971 non-null    int64
#  13  FUELSOLDEASP        971 non-null    int64
#  14  THERMCRCK           971 non-null    int64
#  15  VACMDIST            971 non-null    int64
#  16  Crude_API           971 non-null    float64
#  17  NG_Yield_PAD        971 non-null    float64
#  18  GSL_Yield_PAD       971 non-null    float64
#  19  DSL_Yield_PAD       971 non-null    float64
#  20  RESID_Yield_PAD     971 non-null    float64
#  21  WTI_Price           971 non-null    float64
#  22  WTI_Diff            971 non-null    float64
#  23  WTI_Acq_Cost        971 non-null    float64
#  24  Brent_Price         971 non-null    float64
#  25  Brent_Diff          971 non-null    float64
#  26  CRCK_WTI_PAD-1A     971 non-null    float64
#  27  CRCK_WTI_PAD-1B     971 non-null    float64
#  28  CRCK_WTI_PAD-1C     971 non-null    float64
#  29  CRCK_WTI_PAD-2      971 non-null    float64
#  30  CRCK_WTI_PAD-3      971 non-null    float64
#  31  CRCK_WTI_PAD-4      971 non-null    float64
#  32  CRCK_WTI_PAD-5      971 non-null    float64
#  33  SPECF_CRCK_PAD-1A   971 non-null    float64
#  34  SPECF_CRCK_PAD-1B   971 non-null    float64
#  35  SPECF_CRCK_PAD-1C   971 non-null    float64
#  36  SPECF_CRCK_PAD-2    971 non-null    float64
#  37  SPECF_CRCK_PAD-3    971 non-null    float64
#  38  SPECF_CRCK_PAD-4    971 non-null    float64
#  39  SPECF_CRCK_PAD-5    971 non-null    float64
#  40  SPECF_RFY_CRCK      971 non-null    float64
#  41  Dist_PAD-1A         971 non-null    float64
#  42  Dist_PAD-1B         971 non-null    float64
#  43  Dist_PAD-1C         971 non-null    float64
#  44  Dist_PAD-2          971 non-null    float64
#  45  Dist_PAD-3          971 non-null    float64
#  46  Dist_PAD-4          971 non-null    float64
#  47  Dist_PAD-5          971 non-null    float64
#  48  RFY_Press_PAD-1A    971 non-null    float64
#  49  RFY_Press_PAD-1B    971 non-null    float64
#  50  RFY_Press_PAD-1C    971 non-null    float64
#  51  RFY_Press_PAD-2     971 non-null    float64
#  52  RFY_Press_PAD-3     971 non-null    float64
#  53  RFY_Press_PAD-4     971 non-null    float64
#  54  RFY_Press_PAD-5     971 non-null    float64
#  55  BPD_DENS_PAD-1A     971 non-null    float64
#  56  BPD_DENS_PAD-1B     971 non-null    float64
#  57  BPD_DENS_PAD-1C     971 non-null    float64
#  58  BPD_DENS_PAD-2      971 non-null    float64
#  59  BPD_DENS_PAD-3      971 non-null    float64
#  60  BPD_DENS_PAD-4      971 non-null    float64
#  61  BPD_DENS_PAD-5      971 non-null    float64
#  62  MRKT_RESIST_PAD-1A  971 non-null    float64
#  63  MRKT_RESIST_PAD-1B  971 non-null    float64
#  64  MRKT_RESIST_PAD-1C  971 non-null    float64
#  65  MRKT_RESIST_PAD-2   971 non-null    float64
#  66  MRKT_RESIST_PAD-3   971 non-null    float64
#  67  MRKT_RESIST_PAD-4   971 non-null    float64
#  68  MRKT_RESIST_PAD-5   971 non-null    float64
#  69  REVNUE_PAD-1A       971 non-null    float64
#  70  REVNUE_PAD-1B       971 non-null    float64
#  71  REVNUE_PAD-1C       971 non-null    float64
#  72  REVNUE_PAD-2        971 non-null    float64
#  73  REVNUE_PAD-3        971 non-null    float64
#  74  REVNUE_PAD-4        971 non-null    float64
#  75  REVNUE_PAD-5        971 non-null    float64
# dtypes: float64(60), int64(10), object(6)
# memory usage: 576.7+ KB

# %% [markdown]
# ## 3.2.2 Split out the dataset for further exploration

# %% [markdown]
# Split the data to refinery specific and destination market specific:
# - Refineries: Capacity, Configuration, Yields, Distance to Markets, Refinery Pressure to Markets, and Crack Spreads
# - Destination Markets: Distance to Markets, Market Resistance, Market Value of products (combined Sale Prices per each volume of products yielded from each volume of crude processed

# %%
# Split out refinery specific data as dataframe rfy_df:
rfy_df = data.iloc[:,:41]
rfy_df.head().T
# Out:
#                           0         1         2         3         4
# Series               P_1000    P_1000    P_1000    P_1000    P_1000
# RFY-PADD              PAD-3     PAD-3     PAD-3     PAD-3     PAD-3
# RFY-PAD-Sub           PAD-3     PAD-3     PAD-3     PAD-3     PAD-3
# RFY-PAD-District    PAD-3-3   PAD-3-3   PAD-3-3   PAD-3-4   PAD-3-4
# RFY_ID              RFY-001   RFY-002   RFY-003   RFY-009   RFY-010
# RFY_State           Alabama   Alabama   Alabama  Arkansas  Arkansas
# RFY_BPCD              87500     48000      4100     83000      7500
# CATCRKRECYL        10554395  10554395  10554395  10554395  10554395
# CATHYDRCRCK           21500     21500     21500     21500     21500
# CATHYDTRMT          1433000   1433000   1433000   1433000   1433000
# CATLREFORM          9553650   9553650   9553650   9553650   9553650
# CATLYTCRCK          1935870   1935870   1935870   1935870   1935870
# COKING              3080090   3080090   3080090   3080090   3080090
# FUELSOLDEASP        1530321   1530321   1530321   1530321   1530321
# THERMCRCK            265400    265400    265400    265400    265400
# VACMDIST            1681207   1681207   1681207   1681207   1681207
# Crude_API           30.1708   30.1708   30.1708    29.845    29.845
# NG_Yield_PAD        9.08333   9.08333   9.08333     3.925     3.925
# GSL_Yield_PAD        43.775    43.775    43.775    30.075    30.075
# DSL_Yield_PAD       41.5917   41.5917   41.5917    36.295    36.295
# RESID_Yield_PAD     9.08333   9.08333   9.08333     3.925     3.925
# WTI_Price           97.9058   97.9058   97.9058   97.9058   97.9058
# WTI_Diff            3.64583   3.64583   3.64583   3.64583   3.64583
# WTI_Acq_Cost        101.552   101.552   101.552   101.552   101.552
# Brent_Price         108.637   108.637   108.637   108.637   108.637
# Brent_Diff         -3.89583  -3.89583  -3.89583  -3.89583  -3.89583
# CRCK_WTI_PAD-1A      20.959    20.959    20.959   13.1037   13.1037
# CRCK_WTI_PAD-1B     26.6371   26.6371   26.6371   37.6728   37.6728
# CRCK_WTI_PAD-1C     34.3703   34.3703   34.3703   52.6656   52.6656
# CRCK_WTI_PAD-2       58.213    58.213    58.213   65.8418   65.8418
# CRCK_WTI_PAD-3      68.5526   68.5526   68.5526   68.5526   68.5526
# CRCK_WTI_PAD-4      69.1795   69.1795   69.1795   69.1795   69.1795
# CRCK_WTI_PAD-5      74.6808   74.6808   74.6808   74.6808   74.6808
# SPECF_CRCK_PAD-1A   2.66317     2.629   2.64199   1.74878   1.74529
# SPECF_CRCK_PAD-1B   4.01072   3.97412   3.99609   5.78285   5.77819
# SPECF_CRCK_PAD-1C   4.99185   4.95796   4.94855    8.0222   8.02436
# SPECF_CRCK_PAD-2    9.02915   8.94532   9.03671   10.1226   10.1129
# SPECF_CRCK_PAD-3    9.40236   9.68998   9.51619   8.86816   8.92495
# SPECF_CRCK_PAD-4    8.62617   8.68044   8.68853   8.17321   8.15235
# SPECF_CRCK_PAD-5    11.9619   11.9956   11.9715   11.9093    11.907
# SPECF_RFY_CRCK      50.6854   50.8724   50.7996   54.6271   54.6451

# %%
# Split out market data as a datafeame markets_df:
markets_df = data.iloc[:, np.r_[1:4, 5, 21:24, 41:76, 26:33]]
markets_df.head().T
# Out:
#                            0         1          2         3          4
# RFY-PADD               PAD-3     PAD-3      PAD-3     PAD-3      PAD-3
# RFY-PAD-Sub            PAD-3     PAD-3      PAD-3     PAD-3      PAD-3
# RFY-PAD-District     PAD-3-3   PAD-3-3    PAD-3-3   PAD-3-4    PAD-3-4
# RFY_State            Alabama   Alabama    Alabama  Arkansas   Arkansas
# WTI_Price            97.9058   97.9058    97.9058   97.9058    97.9058
# WTI_Diff             3.64583   3.64583    3.64583   3.64583    3.64583
# WTI_Acq_Cost         101.552   101.552    101.552   101.552    101.552
# Dist_PAD-1A          1418.43   1253.86    1380.43   1574.86    1574.14
# Dist_PAD-1B          1073.78   910.556    1036.33   1222.56    1220.33
# Dist_PAD-1C          655.533     576.8    617.933   911.933    921.467
# Dist_PAD-2           864.353   707.412    872.471   719.882    717.118
# Dist_PAD-3           610.312   654.812    645.438   449.562     463.25
# Dist_PAD-4            1622.5   1521.75    1654.88   1306.88    1308.62
# Dist_PAD-5            2087.2   2064.36    2124.96   1752.96    1758.96
# RFY_Press_PAD-1A      61.688   38.2819    2.97009   52.7032     4.7645
# RFY_Press_PAD-1B      81.488   52.7151    3.95626   67.8906    6.14586
# RFY_Press_PAD-1C     133.479   83.2178    6.63502   91.0154     8.1392
# RFY_Press_PAD-2      101.232    67.853     4.6993   115.297    10.4585
# RFY_Press_PAD-3      143.369   73.3034    6.35228   184.624      16.19
# RFY_Press_PAD-4      53.9291   31.5426    2.47753   63.5103    5.73121
# RFY_Press_PAD-5      41.9222   23.2518    1.92945   47.3485    4.26388
# BPD_DENS_PAD-1A      4.15315   2.57733   0.199962   3.54825   0.320771
# BPD_DENS_PAD-1B      1.68825   1.09214  0.0819649   1.40654   0.127329
# BPD_DENS_PAD-1C      2.24742   1.40116   0.111715   1.53245   0.137041
# BPD_DENS_PAD-2        1.2125  0.812706  0.0562856   1.38096   0.125267
# BPD_DENS_PAD-3         3.095   1.58245   0.137131   3.98559   0.349503
# BPD_DENS_PAD-4       4.40205   2.57472   0.202232   5.18412   0.467818
# BPD_DENS_PAD-5      0.680901  0.377656  0.0313381  0.769035  0.0692541
# MRKT_RESIST_PAD-1A  0.127066  0.125435   0.126055  0.133456    0.13319
# MRKT_RESIST_PAD-1B  0.150569  0.149195    0.15002  0.153502   0.153378
# MRKT_RESIST_PAD-1C  0.145237  0.144251   0.143978  0.152324   0.152365
# MRKT_RESIST_PAD-2   0.155105  0.153665   0.155235  0.153741   0.153593
# MRKT_RESIST_PAD-3   0.137156  0.141351   0.138816  0.129363   0.130191
# MRKT_RESIST_PAD-4   0.124693  0.125477   0.125594  0.118145   0.117843
# MRKT_RESIST_PAD-5   0.160174  0.160625   0.160302  0.159469   0.159439
# REVNUE_PAD-1A        122.511   122.511    122.511   114.655    114.655
# REVNUE_PAD-1B        128.189   128.189    128.189   139.225    139.225
# REVNUE_PAD-1C        135.922   135.922    135.922   154.217    154.217
# REVNUE_PAD-2         159.765   159.765    159.765   167.393    167.393
# REVNUE_PAD-3         170.104   170.104    170.104   170.104    170.104
# REVNUE_PAD-4         170.731   170.731    170.731   170.731    170.731
# REVNUE_PAD-5         176.232   176.232    176.232   176.232    176.232
# CRCK_WTI_PAD-1A       20.959    20.959     20.959   13.1037    13.1037
# CRCK_WTI_PAD-1B      26.6371   26.6371    26.6371   37.6728    37.6728
# CRCK_WTI_PAD-1C      34.3703   34.3703    34.3703   52.6656    52.6656
# CRCK_WTI_PAD-2        58.213    58.213     58.213   65.8418    65.8418
# CRCK_WTI_PAD-3       68.5526   68.5526    68.5526   68.5526    68.5526
# CRCK_WTI_PAD-4       69.1795   69.1795    69.1795   69.1795    69.1795
# CRCK_WTI_PAD-5       74.6808   74.6808    74.6808   74.6808    74.6808

# %% [markdown]
# # 3.3 Explore The Data

# %% [markdown]
# ## 3.3.1 Categorical Features

# %%
data.select_dtypes('object')
# Out:
#      Series RFY-PADD RFY-PAD-Sub RFY-PAD-District   RFY_ID     RFY_State
# 0    P_1000    PAD-3       PAD-3          PAD-3-3  RFY-001       Alabama
# 1    P_1000    PAD-3       PAD-3          PAD-3-3  RFY-002       Alabama
# 2    P_1000    PAD-3       PAD-3          PAD-3-3  RFY-003       Alabama
# 3    P_1000    PAD-3       PAD-3          PAD-3-4  RFY-009      Arkansas
# 4    P_1000    PAD-3       PAD-3          PAD-3-4  RFY-010      Arkansas
# ..      ...      ...         ...              ...      ...           ...
# 966  P_8000    PAD-4       PAD-4            PAD-4  RFY-129       Wyoming
# 967  P_8000    PAD-4       PAD-4            PAD-4  RFY-130       Wyoming
# 968  P_8000    PAD-4       PAD-4            PAD-4  RFY-131       Wyoming
# 969  P_8000    PAD-4       PAD-4            PAD-4  RFY-132       Wyoming
# 970  P_8000    PAD-2       PAD-2           FALCON  RFY-203  North Dakota
#
# [971 rows x 6 columns]

# %% [markdown]
# #### Here, the categorical variables represent the following:
# - Series: 8 groups of observations per each 121-122 refineries
# - RFY-PADD: 5 high-level grouping of refinery locations per the U.S. petroleum allocation districts, (PADD = "Petroleum Administration for Defense Districts")
# - RFY-PAD-Sub: 7 second-level grouping of PADD
# - RFY-PAD-District: 7 lowest level grouping of PADD, there's some overlapping with RFY-PAD-Sub, as some states are divided among PAD-District groups
# - RFY_ID: specific refinery ID; there are 122 unique refineries being observed
# - RFY_State: states, where specific refineries are located

# %% [markdown]
# ## 3.3.2 Distributions

# %%
rfy_df['RFY_ID'].describe()
# Out:
# count         971
# unique        124
# top       RFY-054
# freq            8
# Name: RFY_ID, dtype: object

# %% [markdown]
# We have identified 124 specific refineries, over 971 observations, over 8 series - 121 in the first 5 and 122 in series 6 through 8.

# %% [markdown]
# ### 3.3.2.1 Distribution of refineries

# %%
# Number of refineries per state
rfy_df['RFY_State'].value_counts()/8
# Out:
# Texas            27.000
# Louisiana        16.000
# California       15.000
# Washington        5.000
# Wyoming           5.000
# Oklahoma          5.000
# Utah              4.000
# Montana           4.000
# Illinois          4.000
# Pennsylvania      4.000
# Ohio              4.000
# Alabama           3.000
# Kansas            3.000
# Mississippi       3.000
# North Dakota      2.375
# Arkansas          2.000
# Colorado          2.000
# Indiana           2.000
# New Mexico        2.000
# New Jersey        2.000
# Nevada            1.000
# Tennessee         1.000
# Minnesota         1.000
# Michigan          1.000
# Kentucky          1.000
# Delaware          1.000
# West Virginia     1.000
# Name: RFY_State, dtype: float64

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,10))

(rfy_df['RFY-PAD-District'].value_counts()/8).plot(kind='barh', ax=ax[0])
ax[0].set_title('PAD District')
ax[0].set_xlabel('Refinery Count')

(rfy_df['RFY_State'].value_counts()/8).plot(kind='barh', ax=ax[1])
ax[1].set_title('State')
ax[1].set_xlabel('Refinery Count')

plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# ### 3.3.2.2 Distribution of refinery capacities

# %%
# Refinery capacities per state
(rfy_df.groupby('RFY_State')['RFY_BPCD'].sum()/8).sort_values(ascending=False)
# Out:
# RFY_State
# Texas            5604029.0
# Louisiana        3366666.0
# California       1909171.0
# Illinois         1026865.0
# Washington        651700.0
# Ohio              601800.0
# Pennsylvania      601000.0
# Oklahoma          522800.0
# Indiana           463800.0
# New Jersey        418500.0
# Kansas            403800.0
# Mississippi       393940.0
# Minnesota         335000.0
# Kentucky          291000.0
# Montana           223000.0
# Delaware          182200.0
# Tennessee         180000.0
# Wyoming           168500.0
# Utah              148994.0
# Michigan          140000.0
# Alabama           139600.0
# New Mexico        137000.0
# North Dakota      108750.0
# Colorado          103000.0
# Arkansas           90500.0
# West Virginia      22300.0
# Nevada              2000.0
# Name: RFY_BPCD, dtype: float64

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,10))

(rfy_df.groupby('RFY-PAD-District')['RFY_BPCD'].sum()/8).sort_values(ascending=False).plot(kind='barh', ax=ax[0])
ax[0].set_title('PAD District')
ax[0].set_xlabel('Refinery Capacity')

(rfy_df.groupby('RFY_State')['RFY_BPCD'].sum()/8).sort_values(ascending=False).plot(kind='barh', ax=ax[1])
ax[1].set_title('State')
ax[1].set_xlabel('Refinery Capacity')

plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# ### 3.3.2.3 Distribution of average refinery crackspreads - grouped by state

# %%
specific_crack_array = ['SPECF_CRCK_PAD-1A', 'SPECF_CRCK_PAD-1B', 'SPECF_CRCK_PAD-1C',
                        'SPECF_CRCK_PAD-2', 'SPECF_CRCK_PAD-3', 'SPECF_CRCK_PAD-4',
                        'SPECF_CRCK_PAD-5', 'SPECF_RFY_CRCK']
state_avg_crackspread = rfy_df.groupby('RFY-PAD-District')[specific_crack_array].mean()

# %%
state_avg_crackspread.describe()
# Out:
#        SPECF_CRCK_PAD-1A  SPECF_CRCK_PAD-1B  SPECF_CRCK_PAD-1C  \
# count          12.000000          12.000000          12.000000
# mean            2.826732           3.099140           3.000891
# std             1.102687           1.175848           1.244160
# min             0.773264           1.216936           1.338190
# 25%             2.321743           2.202295           2.059970
# 50%             2.795368           2.925843           3.081425
# 75%             3.726580           3.961220           3.946441
# max             4.468688           5.216081           5.376835
#
#        SPECF_CRCK_PAD-2  SPECF_CRCK_PAD-3  SPECF_CRCK_PAD-4  SPECF_CRCK_PAD-5  \
# count         12.000000         12.000000         12.000000         12.000000
# mean           4.198953          4.327582          3.281330          5.841724
# std            0.862181          0.889776          0.760336          0.978797
# min            3.029907          3.515851          2.202332          4.055758
# 25%            3.557618          3.633705          2.629178          5.240464
# 50%            4.220290          3.844333          3.422418          5.567448
# 75%            4.796982          5.035930          3.684780          6.774266
# max            5.513304          5.976073          4.738073          7.074698
#
#        SPECF_RFY_CRCK
# count       12.000000
# mean        26.576351
# std          5.518647
# min         19.533107
# 25%         22.041081
# 50%         25.628023
# 75%         31.441875
# max         33.800399

# %%
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(18,5))

rfy_df.groupby('RFY-PAD-District')['SPECF_CRCK_PAD-1A'].mean().plot(kind='barh', ax=ax[0], sharex='col')
ax[0].set_title('District PAD-1A')
ax[0].set_xlabel('Specific Refinery Crackspreads')

rfy_df.groupby('RFY-PAD-District')['SPECF_CRCK_PAD-1B'].mean().plot(kind='barh', ax=ax[1], sharex='col')
ax[1].set_title('District PAD-1B')
ax[1].set_xlabel('Specific Refinery Crackspreads')

rfy_df.groupby('RFY-PAD-District')['SPECF_CRCK_PAD-1C'].mean().plot(kind='barh', ax=ax[2], sharex='col')
ax[2].set_title('District PAD-1C')
ax[2].set_xlabel('Specific Refinery Crackspreads')

rfy_df.groupby('RFY-PAD-District')['SPECF_CRCK_PAD-2'].mean().plot(kind='barh', ax=ax[3], sharex='col')
ax[3].set_title('District PAD-2')
ax[3].set_xlabel('Specific Refinery Crackspreads')

plt.subplots_adjust(wspace=0.5)

# %%
fig2, ax2 = plt.subplots(nrows=1, ncols=4, figsize=(18,5))

rfy_df.groupby('RFY-PAD-District')['SPECF_CRCK_PAD-3'].mean().plot(kind='barh', ax=ax2[0], sharex='col')
ax2[0].set_title('District PAD-3')
ax2[0].set_xlabel('Specific Refinery Crackspreads')

rfy_df.groupby('RFY-PAD-District')['SPECF_CRCK_PAD-4'].mean().plot(kind='barh', ax=ax2[1], sharex='col')
ax2[1].set_title('District PAD-4')
ax2[1].set_xlabel('Specific Refinery Crackspreads')

rfy_df.groupby('RFY-PAD-District')['SPECF_CRCK_PAD-5'].mean().plot(kind='barh', ax=ax2[2], sharex='col')
ax2[2].set_title('District PAD-5')
ax2[2].set_xlabel('Specific Refinery Crackspreads')

rfy_df.groupby('RFY-PAD-District')['SPECF_RFY_CRCK'].mean().plot(kind='barh', ax=ax2[3], sharex='col')
ax2[3].set_title('Aggegate of all PADs')
ax2[3].set_xlabel('Specific Refinery Crackspreads')

plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# ### 3.3.2.4 Distribution of average refinery crackspreads - grouped by PAD district

# %%
PAD_District_avg_crackspread = rfy_df.groupby('RFY-PAD-District')['SPECF_RFY_CRCK'].mean()

# %%
PAD_District_avg_crackspread.describe()
# Out:
# count    12.000000
# mean     26.576351
# std       5.518647
# min      19.533107
# 25%      22.041081
# 50%      25.628023
# 75%      31.441875
# max      33.800399
# Name: SPECF_RFY_CRCK, dtype: float64

# %% [markdown]
# Looking at the historgram of crack spread distributions grouped by refinery state and PAD district, we can conclude that a PAD District grouping is a fairly good representation of all specific refineries - in other words, we can rely on aggregating the data at a PAD District level, rather than try to track at a state level

# %% [markdown]
# ## 3.3.3 Numeric Features - Markets

# %%
markets_df.describe().T
# Out:
#                     count         mean         std         min          25%  \
# WTI_Price           971.0    61.764629   20.931174   38.519091    45.916250
# WTI_Diff            971.0    -2.639884    6.066625  -18.304167    -6.049091
# WTI_Acq_Cost        971.0    59.124745   21.725374   31.169091    42.340833
# Dist_PAD-1A         971.0  1853.476975  726.212660  256.571429  1534.428571
# Dist_PAD-1B         971.0  1538.355601  722.433384  107.155556  1191.111111
# Dist_PAD-1C         971.0  1415.035922  712.775962  524.226667   849.733333
# Dist_PAD-2          971.0  1070.188196  468.117886  407.432353   769.794118
# Dist_PAD-3          971.0   947.886213  523.183820  370.731250   478.981250
# Dist_PAD-4          971.0  1147.928270  388.488735  292.300000   978.750000
# Dist_PAD-5          971.0  1493.788334  617.451109  370.188000  1057.120000
# RFY_Press_PAD-1A    971.0   117.201253  162.356565    0.722320    25.816366
# RFY_Press_PAD-1B    971.0   196.339081  405.877739    0.801353    31.686203
# RFY_Press_PAD-1C    971.0   146.565445  159.049503    0.814133    31.699772
# RFY_Press_PAD-2     971.0   178.095653  193.644095    1.163567    45.130864
# RFY_Press_PAD-3     971.0   236.147406  295.597667    1.338016    46.968045
# RFY_Press_PAD-4     971.0   130.319894  102.715726    2.477529    51.129101
# RFY_Press_PAD-5     971.0   118.420621  138.113459    1.929448    39.346946
# BPD_DENS_PAD-1A     971.0     7.890592   10.930680    0.048630     1.738091
# BPD_DENS_PAD-1B     971.0     4.067713    8.408893    0.016602     0.656468
# BPD_DENS_PAD-1C     971.0     2.467754    2.677951    0.013708     0.533736
# BPD_DENS_PAD-2      971.0     2.133132    2.319362    0.013937     0.540553
# BPD_DENS_PAD-3      971.0     5.097859    6.381248    0.028885     1.013928
# BPD_DENS_PAD-4      971.0    10.637561    8.384328    0.202232     4.173491
# BPD_DENS_PAD-5      971.0     1.923390    2.243242    0.031338     0.639074
# MRKT_RESIST_PAD-1A  971.0     0.134166    0.013724    0.080438     0.130000
# MRKT_RESIST_PAD-1B  971.0     0.152236    0.011773    0.101071     0.152193
# MRKT_RESIST_PAD-1C  971.0     0.155661    0.004574    0.143978     0.152664
# MRKT_RESIST_PAD-2   971.0     0.156801    0.003857    0.146450     0.155105
# MRKT_RESIST_PAD-3   971.0     0.142696    0.013470    0.122332     0.129190
# MRKT_RESIST_PAD-4   971.0     0.103789    0.025436    0.046462     0.090066
# MRKT_RESIST_PAD-5   971.0     0.154650    0.010612    0.126592     0.156678
# REVNUE_PAD-1A       971.0    80.712741   23.982261   49.692747    59.572613
# REVNUE_PAD-1B       971.0    78.090187   29.657832   45.176333    53.483461
# REVNUE_PAD-1C       971.0    75.931753   38.214020   33.732186    44.173267
# REVNUE_PAD-2        971.0    84.750520   48.625850   36.171990    45.138206
# REVNUE_PAD-3        971.0    88.635067   52.737184   38.099556    47.369482
# REVNUE_PAD-4        971.0    90.932859   53.111699   39.137557    48.688420
# REVNUE_PAD-5        971.0    95.757607   53.112696   43.120834    53.715854
# CRCK_WTI_PAD-1A     971.0    21.587996    7.055127    5.859100    17.790889
# CRCK_WTI_PAD-1B     971.0    18.965441   10.751665    1.638980     9.625900
# CRCK_WTI_PAD-1C     971.0    16.807008   18.977306   -7.098066     0.605844
# CRCK_WTI_PAD-2      971.0    25.625775   29.039169   -4.283986     0.625846
# CRCK_WTI_PAD-3      971.0    29.510321   33.157719   -4.304080     0.768649
# CRCK_WTI_PAD-4      971.0    31.808113   33.619040   -3.203277     2.895057
# CRCK_WTI_PAD-5      971.0    36.632862   33.547715    0.780001     7.115021
#
#                             50%          75%          max
# WTI_Price             56.984167    64.938333    97.905833
# WTI_Diff              -1.563333     2.219167     8.945833
# WTI_Acq_Cost          50.781667    69.723333   106.851667
# Dist_PAD-1A         1841.857143  2220.000000  3145.000000
# Dist_PAD-1B         1493.888889  1936.555556  2876.444444
# Dist_PAD-1C         1128.533333  1837.133333  2977.266667
# Dist_PAD-2           954.235294  1212.529412  2129.911765
# Dist_PAD-3           685.687500  1446.250000  2249.125000
# Dist_PAD-4          1222.875000  1382.750000  1964.625000
# Dist_PAD-5          1628.800000  1944.760000  2733.880000
# RFY_Press_PAD-1A      52.438117   141.575832  1010.775862
# RFY_Press_PAD-1B      61.988808   186.921180  3126.296143
# RFY_Press_PAD-1C      75.318998   236.584549   700.492850
# RFY_Press_PAD-2      101.231795   252.633643  1064.174240
# RFY_Press_PAD-3      137.445223   281.052558  1402.941091
# RFY_Press_PAD-4      118.042226   188.337559   444.200512
# RFY_Press_PAD-5       70.643525   142.005390   954.700387
# BPD_DENS_PAD-1A        3.530404     9.531614    68.050638
# BPD_DENS_PAD-1B        1.284272     3.872595    64.769972
# BPD_DENS_PAD-1C        1.268162     3.983425    11.794350
# BPD_DENS_PAD-2         1.212499     3.025906    12.746092
# BPD_DENS_PAD-3         2.967114     6.067254    30.286149
# BPD_DENS_PAD-4         9.635377    15.373341    36.258546
# BPD_DENS_PAD-5         1.147394     2.306455    15.506265
# MRKT_RESIST_PAD-1A     0.137272     0.144617     0.151936
# MRKT_RESIST_PAD-1B     0.155406     0.159217     0.161356
# MRKT_RESIST_PAD-1C     0.155636     0.160310     0.162333
# MRKT_RESIST_PAD-2      0.156570     0.160611     0.162715
# MRKT_RESIST_PAD-3      0.144673     0.154931     0.162231
# MRKT_RESIST_PAD-4      0.110837     0.120565     0.153013
# MRKT_RESIST_PAD-5      0.158839     0.159773     0.164714
# REVNUE_PAD-1A         71.038976    86.772556   125.043810
# REVNUE_PAD-1B         67.892580    93.099253   139.224504
# REVNUE_PAD-1C         61.841221    97.241057   157.039379
# REVNUE_PAD-2          67.220110   102.447133   175.618447
# REVNUE_PAD-3          72.656018   101.198907   177.330845
# REVNUE_PAD-4          74.765240   105.340384   181.495988
# REVNUE_PAD-5          80.063102   110.723023   185.024972
# CRCK_WTI_PAD-1A       20.958994    24.282923    41.612776
# CRCK_WTI_PAD-1B       17.125068    24.406669    46.106661
# CRCK_WTI_PAD-1C       11.727733    32.252900    66.142713
# CRCK_WTI_PAD-2        14.882982    49.412634    87.212807
# CRCK_WTI_PAD-3        19.263518    54.564741    98.077511
# CRCK_WTI_PAD-4        21.372740    58.706217   102.242655
# CRCK_WTI_PAD-5        26.670602    64.088856   105.771639

# %%
markets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RFY-PADD            971 non-null    object
#  1   RFY-PAD-Sub         971 non-null    object
#  2   RFY-PAD-District    971 non-null    object
#  3   RFY_State           971 non-null    object
#  4   WTI_Price           971 non-null    float64
#  5   WTI_Diff            971 non-null    float64
#  6   WTI_Acq_Cost        971 non-null    float64
#  7   Dist_PAD-1A         971 non-null    float64
#  8   Dist_PAD-1B         971 non-null    float64
#  9   Dist_PAD-1C         971 non-null    float64
#  10  Dist_PAD-2          971 non-null    float64
#  11  Dist_PAD-3          971 non-null    float64
#  12  Dist_PAD-4          971 non-null    float64
#  13  Dist_PAD-5          971 non-null    float64
#  14  RFY_Press_PAD-1A    971 non-null    float64
#  15  RFY_Press_PAD-1B    971 non-null    float64
#  16  RFY_Press_PAD-1C    971 non-null    float64
#  17  RFY_Press_PAD-2     971 non-null    float64
#  18  RFY_Press_PAD-3     971 non-null    float64
#  19  RFY_Press_PAD-4     971 non-null    float64
#  20  RFY_Press_PAD-5     971 non-null    float64
#  21  BPD_DENS_PAD-1A     971 non-null    float64
#  22  BPD_DENS_PAD-1B     971 non-null    float64
#  23  BPD_DENS_PAD-1C     971 non-null    float64
#  24  BPD_DENS_PAD-2      971 non-null    float64
#  25  BPD_DENS_PAD-3      971 non-null    float64
#  26  BPD_DENS_PAD-4      971 non-null    float64
#  27  BPD_DENS_PAD-5      971 non-null    float64
#  28  MRKT_RESIST_PAD-1A  971 non-null    float64
#  29  MRKT_RESIST_PAD-1B  971 non-null    float64
#  30  MRKT_RESIST_PAD-1C  971 non-null    float64
#  31  MRKT_RESIST_PAD-2   971 non-null    float64
#  32  MRKT_RESIST_PAD-3   971 non-null    float64
#  33  MRKT_RESIST_PAD-4   971 non-null    float64
#  34  MRKT_RESIST_PAD-5   971 non-null    float64
#  35  REVNUE_PAD-1A       971 non-null    float64
#  36  REVNUE_PAD-1B       971 non-null    float64
#  37  REVNUE_PAD-1C       971 non-null    float64
#  38  REVNUE_PAD-2        971 non-null    float64
#  39  REVNUE_PAD-3        971 non-null    float64
#  40  REVNUE_PAD-4        971 non-null    float64
#  41  REVNUE_PAD-5        971 non-null    float64
#  42  CRCK_WTI_PAD-1A     971 non-null    float64
#  43  CRCK_WTI_PAD-1B     971 non-null    float64
#  44  CRCK_WTI_PAD-1C     971 non-null    float64
#  45  CRCK_WTI_PAD-2      971 non-null    float64
#  46  CRCK_WTI_PAD-3      971 non-null    float64
#  47  CRCK_WTI_PAD-4      971 non-null    float64
#  48  CRCK_WTI_PAD-5      971 non-null    float64
# dtypes: float64(45), object(4)
# memory usage: 371.8+ KB

# %% [markdown]
# ### 3.3.3.1 Markets summary data

# %%
markets_df.hist(figsize=(20,20))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# #### Reduce redundant variables
# Crack spread values are derivatives of the WTI indicies and along with the 'WTI Diff' and 'WTI Acq Cost' variables do not add much to the correlations among the market variables.
#
# Also, let's isolate the aggregate average crackspread for all PAD dsitricts and just look at the 'apples to apples' correlations for specific PADs.

# %%
markets_summary = markets_df.iloc[:, np.r_[21:49]]

# %%
markets_summary.shape
# Out:
# (971, 28)

# %%
markets_summary.hist(figsize=(15,15))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# ### 3.3.3.2 USD values per barrel of Crude Oil processed and Products Refined:

# %%
markets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RFY-PADD            971 non-null    object
#  1   RFY-PAD-Sub         971 non-null    object
#  2   RFY-PAD-District    971 non-null    object
#  3   RFY_State           971 non-null    object
#  4   WTI_Price           971 non-null    float64
#  5   WTI_Diff            971 non-null    float64
#  6   WTI_Acq_Cost        971 non-null    float64
#  7   Dist_PAD-1A         971 non-null    float64
#  8   Dist_PAD-1B         971 non-null    float64
#  9   Dist_PAD-1C         971 non-null    float64
#  10  Dist_PAD-2          971 non-null    float64
#  11  Dist_PAD-3          971 non-null    float64
#  12  Dist_PAD-4          971 non-null    float64
#  13  Dist_PAD-5          971 non-null    float64
#  14  RFY_Press_PAD-1A    971 non-null    float64
#  15  RFY_Press_PAD-1B    971 non-null    float64
#  16  RFY_Press_PAD-1C    971 non-null    float64
#  17  RFY_Press_PAD-2     971 non-null    float64
#  18  RFY_Press_PAD-3     971 non-null    float64
#  19  RFY_Press_PAD-4     971 non-null    float64
#  20  RFY_Press_PAD-5     971 non-null    float64
#  21  BPD_DENS_PAD-1A     971 non-null    float64
#  22  BPD_DENS_PAD-1B     971 non-null    float64
#  23  BPD_DENS_PAD-1C     971 non-null    float64
#  24  BPD_DENS_PAD-2      971 non-null    float64
#  25  BPD_DENS_PAD-3      971 non-null    float64
#  26  BPD_DENS_PAD-4      971 non-null    float64
#  27  BPD_DENS_PAD-5      971 non-null    float64
#  28  MRKT_RESIST_PAD-1A  971 non-null    float64
#  29  MRKT_RESIST_PAD-1B  971 non-null    float64
#  30  MRKT_RESIST_PAD-1C  971 non-null    float64
#  31  MRKT_RESIST_PAD-2   971 non-null    float64
#  32  MRKT_RESIST_PAD-3   971 non-null    float64
#  33  MRKT_RESIST_PAD-4   971 non-null    float64
#  34  MRKT_RESIST_PAD-5   971 non-null    float64
#  35  REVNUE_PAD-1A       971 non-null    float64
#  36  REVNUE_PAD-1B       971 non-null    float64
#  37  REVNUE_PAD-1C       971 non-null    float64
#  38  REVNUE_PAD-2        971 non-null    float64
#  39  REVNUE_PAD-3        971 non-null    float64
#  40  REVNUE_PAD-4        971 non-null    float64
#  41  REVNUE_PAD-5        971 non-null    float64
#  42  CRCK_WTI_PAD-1A     971 non-null    float64
#  43  CRCK_WTI_PAD-1B     971 non-null    float64
#  44  CRCK_WTI_PAD-1C     971 non-null    float64
#  45  CRCK_WTI_PAD-2      971 non-null    float64
#  46  CRCK_WTI_PAD-3      971 non-null    float64
#  47  CRCK_WTI_PAD-4      971 non-null    float64
#  48  CRCK_WTI_PAD-5      971 non-null    float64
# dtypes: float64(45), object(4)
# memory usage: 371.8+ KB

# %% [markdown]
# The most important variable for the market specific data is the refined product pricing.

# %%
markets_df[['BPD_DENS_PAD-1A', 'BPD_DENS_PAD-1B', 'BPD_DENS_PAD-1C',
            'BPD_DENS_PAD-2', 'BPD_DENS_PAD-3', 'BPD_DENS_PAD-4', 'BPD_DENS_PAD-5', 'WTI_Price',
            'REVNUE_PAD-1A', 'REVNUE_PAD-1B', 'REVNUE_PAD-1C',
            'REVNUE_PAD-2', 'REVNUE_PAD-3', 'REVNUE_PAD-4', 'REVNUE_PAD-5']].describe()
# Out:
#        BPD_DENS_PAD-1A  BPD_DENS_PAD-1B  BPD_DENS_PAD-1C  BPD_DENS_PAD-2  \
# count       971.000000       971.000000       971.000000      971.000000
# mean          7.890592         4.067713         2.467754        2.133132
# std          10.930680         8.408893         2.677951        2.319362
# min           0.048630         0.016602         0.013708        0.013937
# 25%           1.738091         0.656468         0.533736        0.540553
# 50%           3.530404         1.284272         1.268162        1.212499
# 75%           9.531614         3.872595         3.983425        3.025906
# max          68.050638        64.769972        11.794350       12.746092
#
#        BPD_DENS_PAD-3  BPD_DENS_PAD-4  BPD_DENS_PAD-5   WTI_Price  \
# count      971.000000      971.000000      971.000000  971.000000
# mean         5.097859       10.637561        1.923390   61.764629
# std          6.381248        8.384328        2.243242   20.931174
# min          0.028885        0.202232        0.031338   38.519091
# 25%          1.013928        4.173491        0.639074   45.916250
# 50%          2.967114        9.635377        1.147394   56.984167
# 75%          6.067254       15.373341        2.306455   64.938333
# max         30.286149       36.258546       15.506265   97.905833
#
#        REVNUE_PAD-1A  REVNUE_PAD-1B  REVNUE_PAD-1C  REVNUE_PAD-2  \
# count     971.000000     971.000000     971.000000    971.000000
# mean       80.712741      78.090187      75.931753     84.750520
# std        23.982261      29.657832      38.214020     48.625850
# min        49.692747      45.176333      33.732186     36.171990
# 25%        59.572613      53.483461      44.173267     45.138206
# 50%        71.038976      67.892580      61.841221     67.220110
# 75%        86.772556      93.099253      97.241057    102.447133
# max       125.043810     139.224504     157.039379    175.618447
#
#        REVNUE_PAD-3  REVNUE_PAD-4  REVNUE_PAD-5
# count    971.000000    971.000000    971.000000
# mean      88.635067     90.932859     95.757607
# std       52.737184     53.111699     53.112696
# min       38.099556     39.137557     43.120834
# 25%       47.369482     48.688420     53.715854
# 50%       72.656018     74.765240     80.063102
# 75%      101.198907    105.340384    110.723023
# max      177.330845    181.495988    185.024972

# %%
markets_df[['WTI_Price', 'BPD_DENS_PAD-1A', 'BPD_DENS_PAD-1B', 'BPD_DENS_PAD-1C',
            'BPD_DENS_PAD-2', 'BPD_DENS_PAD-3', 'BPD_DENS_PAD-4', 'BPD_DENS_PAD-5',]].hist(figsize=(20,10))
plt.subplots_adjust(hspace=0.7);

# %%
markets_df[['WTI_Price', 'REVNUE_PAD-1A', 'REVNUE_PAD-1B', 'REVNUE_PAD-1C',
            'REVNUE_PAD-2', 'REVNUE_PAD-3', 'REVNUE_PAD-4', 'REVNUE_PAD-5']].hist(figsize=(20,10))
plt.subplots_adjust(hspace=0.7);

# %% [markdown]
# ## 3.3.4 Numeric Features - Refineries

# %% [markdown]
# ### 3.3.4.1 Refineries Summary data

# %%
rfy_df.describe().T
# Out:
#                    count          mean           std            min  \
# RFY_BPCD           971.0  1.502444e+05  1.363932e+05    2000.000000
# CATCRKRECYL        971.0  6.164398e+06  4.027696e+06  740200.000000
# CATHYDRCRCK        971.0  1.618187e+04  6.775439e+03    1990.000000
# CATHYDTRMT         971.0  8.139435e+05  5.688802e+05   45300.000000
# CATLREFORM         971.0  5.589592e+06  3.642904e+06  603950.000000
# CATLYTCRCK         971.0  1.159364e+06  7.210741e+05  128100.000000
# COKING             971.0  1.821749e+06  1.156687e+06  220860.000000
# FUELSOLDEASP       971.0  8.901303e+05  5.884665e+05   74900.000000
# THERMCRCK          971.0  1.364118e+05  1.157883e+05    6000.000000
# VACMDIST           971.0  9.779975e+05  6.466586e+05   81500.000000
# Crude_API          971.0  3.167411e+01  2.644474e+00      26.115455
# NG_Yield_PAD       971.0  7.284530e+00  1.981088e+00       1.991667
# GSL_Yield_PAD      971.0  4.707790e+01  4.020306e+00      29.492308
# DSL_Yield_PAD      971.0  3.885573e+01  3.820340e+00      26.357143
# RESID_Yield_PAD    971.0  7.297568e+00  1.963678e+00       1.991667
# WTI_Price          971.0  6.176463e+01  2.093117e+01      38.519091
# WTI_Diff           971.0 -2.639884e+00  6.066625e+00     -18.304167
# WTI_Acq_Cost       971.0  5.912475e+01  2.172537e+01      31.169091
# Brent_Price        971.0  6.675539e+01  2.340260e+01      41.010909
# Brent_Diff         971.0 -3.434860e+00  3.408720e+00     -19.925833
# CRCK_WTI_PAD-1A    971.0  2.158800e+01  7.055127e+00       5.859100
# CRCK_WTI_PAD-1B    971.0  1.896544e+01  1.075166e+01       1.638980
# CRCK_WTI_PAD-1C    971.0  1.680701e+01  1.897731e+01      -7.098066
# CRCK_WTI_PAD-2     971.0  2.562578e+01  2.903917e+01      -4.283986
# CRCK_WTI_PAD-3     971.0  2.951032e+01  3.315772e+01      -4.304080
# CRCK_WTI_PAD-4     971.0  3.180811e+01  3.361904e+01      -3.203277
# CRCK_WTI_PAD-5     971.0  3.663286e+01  3.354771e+01       0.780001
# SPECF_CRCK_PAD-1A  971.0  2.919914e+00  1.032831e+00       0.553019
# SPECF_CRCK_PAD-1B  971.0  2.896708e+00  1.676770e+00       0.165653
# SPECF_CRCK_PAD-1C  971.0  2.617847e+00  2.965846e+00      -1.124581
# SPECF_CRCK_PAD-2   971.0  4.011456e+00  4.548614e+00      -0.697068
# SPECF_CRCK_PAD-3   971.0  4.221953e+00  4.805829e+00      -0.698255
# SPECF_CRCK_PAD-4   971.0  3.249297e+00  3.610719e+00      -0.490144
# SPECF_CRCK_PAD-5   971.0  5.689741e+00  5.244113e+00       0.126970
# SPECF_RFY_CRCK     971.0  2.560692e+01  2.295570e+01      -0.609174
#
#                             25%           50%           75%           max
# RFY_BPCD           4.250000e+04  1.122290e+05  2.250000e+05  6.070000e+05
# CATCRKRECYL        3.007400e+06  4.391124e+06  1.055440e+07  1.055440e+07
# CATHYDRCRCK        1.580000e+04  1.760000e+04  2.150000e+04  2.150000e+04
# CATHYDTRMT         3.797000e+05  5.868000e+05  1.433000e+06  1.433000e+06
# CATLREFORM         2.637700e+06  4.067214e+06  9.553650e+06  9.553650e+06
# CATLYTCRCK         5.755000e+05  9.009580e+05  1.935870e+06  1.935870e+06
# COKING             8.311000e+05  1.358935e+06  3.080090e+06  3.080090e+06
# FUELSOLDEASP       5.525000e+05  5.540350e+05  1.530321e+06  1.530321e+06
# THERMCRCK          2.235000e+04  8.000000e+04  2.654000e+05  2.654000e+05
# VACMDIST           6.052850e+05  6.131000e+05  1.681207e+06  1.681207e+06
# Crude_API          3.017083e+01  3.169333e+01  3.309750e+01  3.974333e+01
# NG_Yield_PAD       5.995833e+00  7.316667e+00  8.881818e+00  1.025455e+01
# GSL_Yield_PAD      4.563636e+01  4.719091e+01  4.907500e+01  5.432500e+01
# DSL_Yield_PAD      3.813333e+01  3.949722e+01  4.159167e+01  5.088000e+01
# RESID_Yield_PAD    6.016667e+00  7.316667e+00  8.881818e+00  1.025455e+01
# WTI_Price          4.591625e+01  5.698417e+01  6.493833e+01  9.790583e+01
# WTI_Diff          -6.049091e+00 -1.563333e+00  2.219167e+00  8.945833e+00
# WTI_Acq_Cost       4.234083e+01  5.078167e+01  6.972333e+01  1.068517e+02
# Brent_Price        4.795083e+01  6.435833e+01  7.106083e+01  1.086375e+02
# Brent_Diff        -4.062500e+00 -2.599167e+00 -1.465000e+00  3.049091e+00
# CRCK_WTI_PAD-1A    1.779089e+01  2.095899e+01  2.428292e+01  4.161278e+01
# CRCK_WTI_PAD-1B    9.625900e+00  1.712507e+01  2.440667e+01  4.610666e+01
# CRCK_WTI_PAD-1C    6.058438e-01  1.172773e+01  3.225290e+01  6.614271e+01
# CRCK_WTI_PAD-2     6.258460e-01  1.488298e+01  4.941263e+01  8.721281e+01
# CRCK_WTI_PAD-3     7.686488e-01  1.926352e+01  5.456474e+01  9.807751e+01
# CRCK_WTI_PAD-4     2.895057e+00  2.137274e+01  5.870622e+01  1.022427e+02
# CRCK_WTI_PAD-5     7.115021e+00  2.667060e+01  6.408886e+01  1.057716e+02
# SPECF_CRCK_PAD-1A  2.437275e+00  2.781674e+00  3.245073e+00  6.322471e+00
# SPECF_CRCK_PAD-1B  1.481242e+00  2.670676e+00  3.799182e+00  7.439572e+00
# SPECF_CRCK_PAD-1C  9.337595e-02  1.864307e+00  5.011900e+00  1.007780e+01
# SPECF_CRCK_PAD-2   9.699781e-02  2.416813e+00  7.980382e+00  1.408529e+01
# SPECF_CRCK_PAD-3   9.690360e-02  2.854649e+00  8.517118e+00  1.546044e+01
# SPECF_CRCK_PAD-4   2.865716e-01  1.754871e+00  5.411142e+00  1.358204e+01
# SPECF_CRCK_PAD-5   1.121614e+00  3.573081e+00  9.832112e+00  1.693598e+01
# SPECF_RFY_CRCK     5.776357e+00  1.796004e+01  4.582628e+01  7.506894e+01

# %%
rfy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Series             971 non-null    object
#  1   RFY-PADD           971 non-null    object
#  2   RFY-PAD-Sub        971 non-null    object
#  3   RFY-PAD-District   971 non-null    object
#  4   RFY_ID             971 non-null    object
#  5   RFY_State          971 non-null    object
#  6   RFY_BPCD           971 non-null    int64
#  7   CATCRKRECYL        971 non-null    int64
#  8   CATHYDRCRCK        971 non-null    int64
#  9   CATHYDTRMT         971 non-null    int64
#  10  CATLREFORM         971 non-null    int64
#  11  CATLYTCRCK         971 non-null    int64
#  12  COKING             971 non-null    int64
#  13  FUELSOLDEASP       971 non-null    int64
#  14  THERMCRCK          971 non-null    int64
#  15  VACMDIST           971 non-null    int64
#  16  Crude_API          971 non-null    float64
#  17  NG_Yield_PAD       971 non-null    float64
#  18  GSL_Yield_PAD      971 non-null    float64
#  19  DSL_Yield_PAD      971 non-null    float64
#  20  RESID_Yield_PAD    971 non-null    float64
#  21  WTI_Price          971 non-null    float64
#  22  WTI_Diff           971 non-null    float64
#  23  WTI_Acq_Cost       971 non-null    float64
#  24  Brent_Price        971 non-null    float64
#  25  Brent_Diff         971 non-null    float64
#  26  CRCK_WTI_PAD-1A    971 non-null    float64
#  27  CRCK_WTI_PAD-1B    971 non-null    float64
#  28  CRCK_WTI_PAD-1C    971 non-null    float64
#  29  CRCK_WTI_PAD-2     971 non-null    float64
#  30  CRCK_WTI_PAD-3     971 non-null    float64
#  31  CRCK_WTI_PAD-4     971 non-null    float64
#  32  CRCK_WTI_PAD-5     971 non-null    float64
#  33  SPECF_CRCK_PAD-1A  971 non-null    float64
#  34  SPECF_CRCK_PAD-1B  971 non-null    float64
#  35  SPECF_CRCK_PAD-1C  971 non-null    float64
#  36  SPECF_CRCK_PAD-2   971 non-null    float64
#  37  SPECF_CRCK_PAD-3   971 non-null    float64
#  38  SPECF_CRCK_PAD-4   971 non-null    float64
#  39  SPECF_CRCK_PAD-5   971 non-null    float64
#  40  SPECF_RFY_CRCK     971 non-null    float64
# dtypes: float64(25), int64(10), object(6)
# memory usage: 311.1+ KB

# %%
rfy_df.hist(figsize=(20,20))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# ### 3.3.4.2 Crack spreads specific to refineries:

# %%
# Grouped by State:
rfy_df.groupby('RFY_State')['SPECF_RFY_CRCK'].describe()
# Out:
#                count       mean        std       min        25%        50%  \
# RFY_State
# Alabama         24.0  24.245853  22.134764  5.095755   5.866990  14.976721
# Arkansas        16.0  27.152198  22.982243  7.180653   8.312487  17.766788
# California     120.0  19.507375  20.862626  1.071331   1.857260  10.759790
# Colorado        16.0  33.765910  25.252467  9.272017  12.740935  22.716257
# Delaware         8.0  19.553279  24.745516 -0.441348   0.280076   9.351338
# Illinois        32.0  31.072305  25.306993  6.112678   9.673069  20.273740
# Indiana         16.0  31.111111  25.791657  6.086913   9.645379  20.301812
# Kansas          24.0  30.874816  24.928522  6.565122   9.777748  20.182703
# Kentucky         8.0  31.379593  27.225798  5.960986   9.510539  20.339107
# Louisiana      128.0  24.066082  21.405403  5.195133   5.978672  14.939018
# Michigan         8.0  31.305703  27.327144  5.802876   9.375092  20.225300
# Minnesota        8.0  32.349089  26.388133  7.151826  11.122605  21.961088
# Mississippi     24.0  24.163256  21.974349  5.151527   5.926357  14.955506
# Montana         32.0  33.868629  25.115248  9.089172  12.573252  22.705197
# Nevada           8.0  19.531775  22.154089  1.132174   1.937526  10.818490
# New Jersey      16.0  19.523021  24.035386 -0.609174   0.048099   9.302325
# New Mexico      16.0  21.230136  20.450985  3.884435   4.231160  12.704898
# North Dakota    19.0  32.317301  22.901800  7.359299  11.641100  26.252302
# Ohio            32.0  31.349351  25.959060  5.768678   9.382914  20.280289
# Oklahoma        40.0  30.890204  24.718532  6.577487   9.793258  20.214581
# Pennsylvania    32.0  22.358326  23.968373  1.475987   2.504105  12.341245
# Tennessee        8.0  31.002393  26.375394  6.306957   9.806853  20.297264
# Texas          216.0  23.390447  20.915001  4.895743   5.564506  14.468815
# Utah            32.0  33.758210  24.914387  9.203518  12.668690  22.671968
# Washington      40.0  19.673738  21.239469  1.070293   1.839726  10.859669
# West Virginia    8.0  22.123679  24.678339  1.803237   2.766053  12.297351
# Wyoming         40.0  33.793363  24.850562  9.154476  12.648078  22.703359
#
#                      75%        max
# RFY_State
# Alabama        36.322042  65.314953
# Arkansas       39.340769  69.320763
# California     30.934844  58.231501
# Colorado       53.169117  73.230533
# Delaware       31.895411  63.289593
# Illinois       49.712769  73.268100
# Indiana        49.821002  73.407137
# Kansas         49.223227  72.154824
# Kentucky       50.371353  74.440731
# Louisiana      35.947730  64.706842
# Michigan       50.348705  74.550580
# Minnesota      51.197227  73.956507
# Mississippi    36.132414  64.982923
# Montana        53.446435  73.982823
# Nevada         30.925664  58.070071
# New Jersey     31.914568  63.624081
# New Mexico     32.565304  59.005843
# North Dakota   45.832565  72.797941
# Ohio           50.452822  75.068945
# Oklahoma       49.214029  72.092237
# Pennsylvania   34.919737  67.250756
# Tennessee      49.547084  72.600679
# Texas          35.079221  63.178614
# Utah           53.197897  73.369358
# Washington     31.212852  58.700079
# West Virginia  34.390987  65.541196
# Wyoming        53.312720  73.774812

# %%
# Grouped by PAD Districts:
rfy_df.groupby('RFY-PAD-District')['SPECF_RFY_CRCK'].describe()
# Out:
#                   count       mean        std        min        25%  \
# RFY-PAD-District
# FALCON              3.0  33.594073   7.556047  26.480953  29.627958
# PAD-1-1            24.0  19.533107  23.730265  -0.609174   0.057761
# PAD-1-2            40.0  22.311397  23.789928   1.475987   2.519282
# PAD-2-1           104.0  31.199733  25.315434   5.768678   9.481823
# PAD-2-2            24.0  32.168301  24.843507   7.151826  11.187476
# PAD-2-3            64.0  30.884434  24.599054   6.565122   9.783493
# PAD-3-2           216.0  23.390447  20.915001   4.895743   5.564506
# PAD-3-3           176.0  24.103847  21.456387   5.095755   5.902501
# PAD-3-4            16.0  27.152198  22.982243   7.180653   8.312487
# PAD-3-5            16.0  21.230136  20.450985   3.884435   4.231160
# PAD-4             120.0  33.800399  24.673766   9.089172  12.597077
# PAD-5             168.0  19.548147  20.882419   1.070293   1.861329
#
#                         50%        75%        max
# RFY-PAD-District
# FALCON            32.774962  37.150633  41.526303
# PAD-1-1            9.321501  31.904083  63.624081
# PAD-1-2           12.297351  34.804513  67.250756
# PAD-2-1           20.295656  50.131686  75.068945
# PAD-2-2           21.919214  50.926790  73.956507
# PAD-2-3           20.199749  49.223227  72.154824
# PAD-3-2           14.468815  35.079221  63.178614
# PAD-3-3           14.939018  36.108449  65.314953
# PAD-3-4           17.766788  39.340769  69.320763
# PAD-3-5           12.704898  32.565304  59.005843
# PAD-4             22.704132  53.343885  73.982823
# PAD-5             10.792815  31.105148  58.700079

# %% [markdown]
# ## 3.3.5 Feature Values

# %% [markdown]
# We identify the feature values as follows:
# - 'RFY_BPCD' - refinery operating capacity in Barrels per Calendar Day
# - 'DIST_PAD_' - cumulative distances from each refinery to each of the destination markets (PAD Districts)
# - 'MRKT_RESIST_PAD_' - a perceived resistance of each destination market to supply; the resistance is a measure of how much BPCD needs to travel to a given destination market per 1MM of its population.
# - 'CATCRKRECYL' through 'VACMDIST' are refinery configuration specifics, indicating the type of petroleum products they're capable of yielding from processing raw crude oils
# - 'Brent Price' and 'WTI Price' - are crude oil market prices, and the 'Diff' refers to perceived discounts/premiums refineries get. The 'Diffs' are dictated by the going market, but mainly depend on the refineries' geographical locations, i.e., proximity to crude source, whether domestic or imported.
# - 'Crude API' - indicates the type of crude oil, e.g., heavy, light, sweet, etc.; this determines the type and yield ratio of petroleum products that could be extracted from it, depending on refinery configuration
# - 'Yields' are the expected volumetric ratios of refined petroleum products at refineries; here, grouped into just 4 categories - NG (Propane, Butane), GSL (Naphtha, Gasolines), DSL (kerosene, jet fuel, diesel, some lighter fuel oils), RESID (heavier fuel oils, lubricants, residual oil, etc.)
# - 'REVNUE_PAD_' - perceived market value of the refined products at the destination markets; the calculation is based on historical wholesale prices, multiplied by the volumes in a given market district
# - 'CRCK_WTI_PAD_' - "crack spread", or a perceived gross profit margin, calculated as the difference between 'REVNUE_' and the 'WTI_Acq_Cost', i.e. between the combined Sales price for all products and WTI crude price market index.
#
# **We will use crack spread as the main indicator of economic feasibility of a given refinery.**
#
# - 'SPECF_RFY_CRCK' - the ultimate crack spread a given refinery is likely to achieve, given the potential crack spreads at each of the 7 destination markets (PAD Districts), but conditioned by the market resistance
#
# **We will use the 'SPECF_RFY_CRCK' as the target variable during the modeling stage.**

# %% [markdown]
# ### 3.3.5.1 Distances between Refineries and Markets by PAD district

# %% [markdown]
# #### Refineries to Destination Markets

# %%
distances = data.iloc[:,np.r_[41:48]]

# %% [markdown]
# #### Distribution of cumulative "Refinery to Destination Market" distances by PAD districts

# %%
distances.hist(figsize=(15, 10))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# ### 3.3.5.2 Refinery Supply Pressure and Market Resistance

# %% [markdown]
# #### "Refinery Supply Pressure to Markets" vs. "Product Supply per capita at Markets" vs. Market Resistance

# %%
supply_pressure = data.iloc[:,np.r_[48:69]]

# %% [markdown]
# #### Distribution of Refinery Supply Pressure, Supply per capita at Markets, and Market Resistance

# %%
supply_pressure.hist(figsize=(15, 15))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# #### Reduce redundant feature variables
# It is apparent from the histrogram subplots that the variables for "Refinery Pressure to Markets" and "Product Supply per capita at Markets" look identical, even thought their absolute values are different.
#
# We will keep just the first set ('RFY_Press_') for use during Feature Engineering and drop the second ('BPD_DENS_').

# %%
supply_pressure = data.iloc[:,np.r_[55:69]]

# %%
supply_pressure.hist(figsize=(15, 15))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# # 3.4. Visualizing Correlations

# %% [markdown]
# #### Now let's look at some correlations:
# * between refinery and market PAD districts
# * between specific refineries and the features

# %% [markdown]
# ## 3.4.1 Market Variables Correlations

# %% [markdown]
# ### 3.4.1.1 Scale the Data

# %%
# get refinery PAD District to use as index 'RFY-PAD-District'
rfy_PAD_labels = data['RFY-PAD-District']

# %%
# store column names:
markets_summary_columns = markets_summary.columns

# %%
# scale the markets data - generates an ndarray
markets_summary_scale = scale(markets_summary)

# %%
# construct a dataframe using the ndarray and stored column names:
markets_summary_scaled_df = pd.DataFrame(markets_summary_scale, columns=markets_summary_columns)
markets_summary_scaled_df.head()
# Out:
#    BPD_DENS_PAD-1A  BPD_DENS_PAD-1B  BPD_DENS_PAD-1C  BPD_DENS_PAD-2  \
# 0        -0.342098        -0.283115        -0.082321       -0.397138
# 1        -0.486337        -0.354043        -0.398494       -0.569599
# 2        -0.703945        -0.474236        -0.880245       -0.895900
# 3        -0.397467        -0.316634        -0.349442       -0.324468
# 4        -0.692887        -0.468839        -0.870783       -0.866143
#
#    BPD_DENS_PAD-3  BPD_DENS_PAD-4  BPD_DENS_PAD-5  MRKT_RESIST_PAD-1A  \
# 0       -0.314028       -0.744094       -0.554166           -0.517640
# 1       -0.551181       -0.962152       -0.689418           -0.636521
# 2       -0.777792       -1.245264       -0.843880           -0.591328
# 3       -0.174393       -0.650767       -0.514858           -0.051764
# 4       -0.744494       -1.213572       -0.826969           -0.071183
#
#    MRKT_RESIST_PAD-1B  MRKT_RESIST_PAD-1C  ...  REVNUE_PAD-3  REVNUE_PAD-4  \
# 0           -0.141668           -2.280250  ...      1.545611      1.503235
# 1           -0.258442           -2.495923  ...      1.545611      1.503235
# 2           -0.188333           -2.555789  ...      1.545611      1.503235
# 3            0.107580           -0.730146  ...      1.545611      1.503235
# 4            0.097065           -0.721171  ...      1.545611      1.503235
#
#    REVNUE_PAD-5  CRCK_WTI_PAD-1A  CRCK_WTI_PAD-1B  CRCK_WTI_PAD-1C  \
# 0      1.515953        -0.089201          0.71390         0.925965
# 1      1.515953        -0.089201          0.71390         0.925965
# 2      1.515953        -0.089201          0.71390         0.925965
# 3      1.515953        -1.203184          1.74085         1.890523
# 4      1.515953        -1.203184          1.74085         1.890523
#
#    CRCK_WTI_PAD-2  CRCK_WTI_PAD-3  CRCK_WTI_PAD-4  CRCK_WTI_PAD-5
# 0        1.122761        1.178077        1.112185        1.134729
# 1        1.122761        1.178077        1.112185        1.134729
# 2        1.122761        1.178077        1.112185        1.134729
# 3        1.385603        1.178077        1.112185        1.134729
# 4        1.385603        1.178077        1.112185        1.134729
#
# [5 rows x 28 columns]

# %% [markdown]
# #### 3.4.1.2 Verify Scaling

# %%
markets_summary_scaled_df.mean()
# Out:
# BPD_DENS_PAD-1A      -3.510180e-17
# BPD_DENS_PAD-1B      -1.028471e-16
# BPD_DENS_PAD-1C      -3.098563e-17
# BPD_DENS_PAD-2       -1.668193e-16
# BPD_DENS_PAD-3        5.008009e-17
# BPD_DENS_PAD-4       -1.797395e-16
# BPD_DENS_PAD-5       -1.326322e-17
# MRKT_RESIST_PAD-1A    4.907392e-16
# MRKT_RESIST_PAD-1B   -3.775444e-16
# MRKT_RESIST_PAD-1C    3.573295e-15
# MRKT_RESIST_PAD-2     3.779389e-15
# MRKT_RESIST_PAD-3     1.158817e-15
# MRKT_RESIST_PAD-4    -1.098789e-16
# MRKT_RESIST_PAD-5     1.869885e-15
# REVNUE_PAD-1A         1.501031e-15
# REVNUE_PAD-1B         4.797627e-16
# REVNUE_PAD-1C         6.144530e-16
# REVNUE_PAD-2         -1.343473e-15
# REVNUE_PAD-3          2.651386e-15
# REVNUE_PAD-4         -1.812831e-15
# REVNUE_PAD-5         -8.964108e-17
# CRCK_WTI_PAD-1A      -1.144181e-15
# CRCK_WTI_PAD-1B      -1.413562e-15
# CRCK_WTI_PAD-1C      -2.186602e-15
# CRCK_WTI_PAD-2       -1.931707e-15
# CRCK_WTI_PAD-3        1.057828e-15
# CRCK_WTI_PAD-4        7.717822e-17
# CRCK_WTI_PAD-5       -2.414092e-15
# dtype: float64

# %%
markets_summary_scaled_df.std()
# Out:
# BPD_DENS_PAD-1A       1.000515
# BPD_DENS_PAD-1B       1.000515
# BPD_DENS_PAD-1C       1.000515
# BPD_DENS_PAD-2        1.000515
# BPD_DENS_PAD-3        1.000515
# BPD_DENS_PAD-4        1.000515
# BPD_DENS_PAD-5        1.000515
# MRKT_RESIST_PAD-1A    1.000515
# MRKT_RESIST_PAD-1B    1.000515
# MRKT_RESIST_PAD-1C    1.000515
# MRKT_RESIST_PAD-2     1.000515
# MRKT_RESIST_PAD-3     1.000515
# MRKT_RESIST_PAD-4     1.000515
# MRKT_RESIST_PAD-5     1.000515
# REVNUE_PAD-1A         1.000515
# REVNUE_PAD-1B         1.000515
# REVNUE_PAD-1C         1.000515
# REVNUE_PAD-2          1.000515
# REVNUE_PAD-3          1.000515
# REVNUE_PAD-4          1.000515
# REVNUE_PAD-5          1.000515
# CRCK_WTI_PAD-1A       1.000515
# CRCK_WTI_PAD-1B       1.000515
# CRCK_WTI_PAD-1C       1.000515
# CRCK_WTI_PAD-2        1.000515
# CRCK_WTI_PAD-3        1.000515
# CRCK_WTI_PAD-4        1.000515
# CRCK_WTI_PAD-5        1.000515
# dtype: float64

# %% [markdown]
# Scaling verification is good - mean is close to zero and standard deviation is close to 1

# %% [markdown]
# #### 3.4.1.3 PCA

# %% [markdown]
# ##### Fit the PCA transformation

# %%
markets_pca = PCA().fit(markets_summary_scale)

# %% [markdown]
# ##### Plot PCA

# %%
plt.subplots(figsize=(10, 6))
plt.plot(markets_pca.explained_variance_ratio_.cumsum())
plt.xlabel('Component #')
plt.ylabel('Cumulative ratio variance')
plt.title('Cumulative variance ratio explained by PCA components for market/refinery summary statistics');

# %% [markdown]
# Apply PCA transformation to markets summary data and obtain derived features

# %%
markets_pca_x = markets_pca.transform(markets_summary_scale)

# %%
markets_pca_x.shape
# Out:
# (971, 28)

# %% [markdown]
# Plot the first two derived features

# %%
x = markets_pca_x[:, 0]
y = markets_pca_x[:, 1]

refinery_target = rfy_PAD_labels

pc_var = 100 * markets_pca.explained_variance_ratio_.cumsum()[1]

plt.subplots(figsize=(18,9))
plt.scatter(x=x, y=y)
plt.xlabel('First component')
plt.ylabel('Second component')
plt.title(f'Refinery markets summary PCA, {pc_var:.1f}% variance explained')

for s, x, y in zip(refinery_target, x, y):
    plt.annotate(s, (x, y))

# %% [markdown]
# ##### Add specific refinery aggregate crackspreads to PCA scatter plot

# %%
# PCA dataframe:
pca_df = pd.DataFrame({'PC1': markets_pca_x[:,0], 'PC2': markets_pca_x[:,1]}, index=refinery_target)
pca_df.head()
# Out:
#                        PC1       PC2
# RFY-PAD-District
# PAD-3-3           4.722315  0.854203
# PAD-3-3           4.734231  0.685057
# PAD-3-3           4.740195  0.084035
# PAD-3-4           5.363316  0.280088
# PAD-3-4           5.382899 -0.510566

# %%
rfy_crack = data[['RFY-PAD-District','SPECF_RFY_CRCK']]

# set Refinery PAD District as index
rfy_crack = rfy_crack.set_index('RFY-PAD-District')

# %%
rfy_crack.head(3)
# Out:
#                   SPECF_RFY_CRCK
# RFY-PAD-District
# PAD-3-3                50.685368
# PAD-3-3                50.872421
# PAD-3-3                50.799553

# %%
pca_df.head(3)
# Out:
#                        PC1       PC2
# RFY-PAD-District
# PAD-3-3           4.722315  0.854203
# PAD-3-3           4.734231  0.685057
# PAD-3-3           4.740195  0.084035

# %% [markdown]
# Concatenate PCA components and Specific Refinery Crackspreads into one dataframe - on a RFY PAD District index

# %%
pca_crack_df = pd.concat([pca_df, rfy_crack], axis=1)
pca_crack_df.head()
# Out:
#                        PC1       PC2  SPECF_RFY_CRCK
# RFY-PAD-District
# PAD-3-3           4.722315  0.854203       50.685368
# PAD-3-3           4.734231  0.685057       50.872421
# PAD-3-3           4.740195  0.084035       50.799553
# PAD-3-4           5.363316  0.280088       54.627084
# PAD-3-4           5.382899 -0.510566       54.645053

# %% [markdown]
# Separate the crack spread distribution into quartiles

# %%
pca_crack_q_series = pd.cut(pca_crack_df['SPECF_RFY_CRCK'], 4, precision=1)
pca_crack_df['Quartile'] = pca_crack_q_series
pca_crack_df.head()
# Out:
#                        PC1       PC2  SPECF_RFY_CRCK      Quartile
# RFY-PAD-District
# PAD-3-3           4.722315  0.854203       50.685368  (37.2, 56.1]
# PAD-3-3           4.734231  0.685057       50.872421  (37.2, 56.1]
# PAD-3-3           4.740195  0.084035       50.799553  (37.2, 56.1]
# PAD-3-4           5.363316  0.280088       54.627084  (37.2, 56.1]
# PAD-3-4           5.382899 -0.510566       54.645053  (37.2, 56.1]

# %%
pca_crack_df.dtypes
# Out:
# PC1                float64
# PC2                float64
# SPECF_RFY_CRCK     float64
# Quartile          category
# dtype: object

# %% [markdown]
# ##### Recreate the PCA scatter plot with refinery crack spread values

# %%
pca_crack_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 971 entries, PAD-3-3 to FALCON
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PC1             971 non-null    float64
#  1   PC2             971 non-null    float64
#  2   SPECF_RFY_CRCK  971 non-null    float64
#  3   Quartile        971 non-null    category
# dtypes: category(1), float64(3)
# memory usage: 31.5+ KB

# %%
# only get the first 121 refinery observations (Series 1) for a clearer chart
pca_crack_df_121 = pca_crack_df.iloc[np.r_[0:121],:]

# %%
pca_crack_df_121.shape
# Out:
# (121, 4)

# %%
# only get 121 refineries from Series 1 out of 8 for a clearer chart
x = pca_crack_df_121.PC1
y = pca_crack_df_121.PC2

crack = pca_crack_df_121.SPECF_RFY_CRCK
quartiles = pca_crack_df_121.Quartile
market = pca_crack_df_121.index

pc_var = 100 * markets_pca.explained_variance_ratio_.cumsum()[1]

fig, ax = plt.subplots(figsize=(15,7))

for q in quartiles.cat.categories:
    im = quartiles == q
    ax.scatter(x=x[im], y=y[im], s=crack[im], label=q)
ax.set_xlabel('First component')
ax.set_ylabel('Second component')

plt.legend()
ax.set_title(f'Markets summary PCA, {pc_var:.1f}% variance explained')

for s, x, y in zip(market, x, y):
    plt.annotate(s, (x, y))

# %% [markdown]
# There's a pattern how the quartile values of crack spreads, achieved by specific refineries are distributed across the PAD districts

# %% [markdown]
# ##### Recreate the PCA plot using seaborn:

# %%
x = pca_crack_df_121.PC1
y = pca_crack_df_121.PC2

market = pca_crack_df_121.index

plt.subplots(figsize=(15, 10))

sns.scatterplot(x='PC1', y='PC2', size='SPECF_RFY_CRCK', hue='Quartile', 
                 hue_order=pca_crack_df_121.Quartile.cat.categories, data=pca_crack_df_121)

for s, x, y in zip(market, x, y):
    plt.annotate(s, (x, y))   
plt.title(f'Markets summary PCA, {pc_var:.1f}% variance explained');

# %% [markdown]
# ##### Conclusion on the PCA analysis of the market districts
# There is a clear grouping of refinery economic performance, depending on their target markets

# %% [markdown]
# ## 3.4.2 Refinery Variables Correlations

# %%
rfy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Series             971 non-null    object
#  1   RFY-PADD           971 non-null    object
#  2   RFY-PAD-Sub        971 non-null    object
#  3   RFY-PAD-District   971 non-null    object
#  4   RFY_ID             971 non-null    object
#  5   RFY_State          971 non-null    object
#  6   RFY_BPCD           971 non-null    int64
#  7   CATCRKRECYL        971 non-null    int64
#  8   CATHYDRCRCK        971 non-null    int64
#  9   CATHYDTRMT         971 non-null    int64
#  10  CATLREFORM         971 non-null    int64
#  11  CATLYTCRCK         971 non-null    int64
#  12  COKING             971 non-null    int64
#  13  FUELSOLDEASP       971 non-null    int64
#  14  THERMCRCK          971 non-null    int64
#  15  VACMDIST           971 non-null    int64
#  16  Crude_API          971 non-null    float64
#  17  NG_Yield_PAD       971 non-null    float64
#  18  GSL_Yield_PAD      971 non-null    float64
#  19  DSL_Yield_PAD      971 non-null    float64
#  20  RESID_Yield_PAD    971 non-null    float64
#  21  WTI_Price          971 non-null    float64
#  22  WTI_Diff           971 non-null    float64
#  23  WTI_Acq_Cost       971 non-null    float64
#  24  Brent_Price        971 non-null    float64
#  25  Brent_Diff         971 non-null    float64
#  26  CRCK_WTI_PAD-1A    971 non-null    float64
#  27  CRCK_WTI_PAD-1B    971 non-null    float64
#  28  CRCK_WTI_PAD-1C    971 non-null    float64
#  29  CRCK_WTI_PAD-2     971 non-null    float64
#  30  CRCK_WTI_PAD-3     971 non-null    float64
#  31  CRCK_WTI_PAD-4     971 non-null    float64
#  32  CRCK_WTI_PAD-5     971 non-null    float64
#  33  SPECF_CRCK_PAD-1A  971 non-null    float64
#  34  SPECF_CRCK_PAD-1B  971 non-null    float64
#  35  SPECF_CRCK_PAD-1C  971 non-null    float64
#  36  SPECF_CRCK_PAD-2   971 non-null    float64
#  37  SPECF_CRCK_PAD-3   971 non-null    float64
#  38  SPECF_CRCK_PAD-4   971 non-null    float64
#  39  SPECF_CRCK_PAD-5   971 non-null    float64
#  40  SPECF_RFY_CRCK     971 non-null    float64
# dtypes: float64(25), int64(10), object(6)
# memory usage: 311.1+ KB

# %% [markdown]
# ### 3.4.2.1 Visualize correlations for Refineries

# %% [markdown]
# Let's select some useful variables for vizualizing correlations between refinery specific variables

# %% [markdown]
# #### Let's see how refinery configurations and the Crude APIs correlate with the refined product yields
# - Refinery configuration variables: 'CATCRKRECYL' through 'VACMDIST'
# - Crude characteristics: 'CRUDE_API'
# - Yeields: 'GSL_Yield' and 'DSL_Yield'; we will omit the 'NG' and 'RESID', as in this analysis, we mainly are concerned with the high-value products, which are gasolines and diesel fractions

# %%
rfy_corr = rfy_df.iloc[:, np.r_[7:17, 18:21]]
rfy_corr.tail()
# Out:
#      CATCRKRECYL  CATHYDRCRCK  CATHYDTRMT  CATLREFORM  CATLYTCRCK   COKING  \
# 966       740200         1990       60200      603950      128100   220860
# 967       740200         1990       60200      603950      128100   220860
# 968       740200         1990       60200      603950      128100   220860
# 969       740200         1990       60200      603950      128100   220860
# 970      4391124        15800      379700     4067214      900958  1358935
#
#      FUELSOLDEASP  THERMCRCK  VACMDIST  Crude_API  GSL_Yield_PAD  \
# 966         81750       6000     87970  32.240000      46.790909
# 967         81750       6000     87970  32.240000      46.790909
# 968         81750       6000     87970  32.240000      46.790909
# 969         81750       6000     87970  32.240000      46.790909
# 970        554035      22350    605285  26.115455      41.750000
#
#      DSL_Yield_PAD  RESID_Yield_PAD
# 966      38.481818         5.281818
# 967      38.481818         5.281818
# 968      38.481818         5.281818
# 969      38.481818         5.281818
# 970      50.880000         6.770000

# %%
rfy_corr.corr(method='pearson')
# Out:
#                  CATCRKRECYL  CATHYDRCRCK  CATHYDTRMT  CATLREFORM  CATLYTCRCK  \
# CATCRKRECYL         1.000000     0.840717    0.976577    0.999762    0.998675
# CATHYDRCRCK         0.840717     1.000000    0.857990    0.838645    0.849290
# CATHYDTRMT          0.976577     0.857990    1.000000    0.972869    0.967772
# CATLREFORM          0.999762     0.838645    0.972869    1.000000    0.999379
# CATLYTCRCK          0.998675     0.849290    0.967772    0.999379    1.000000
# COKING              0.998532     0.830037    0.967021    0.999454    0.999207
# FUELSOLDEASP        0.994152     0.865739    0.993466    0.992119    0.989661
# THERMCRCK           0.956268     0.775157    0.987453    0.952709    0.943482
# VACMDIST            0.993644     0.866782    0.993924    0.991548    0.989050
# Crude_API          -0.067890    -0.287034   -0.199882   -0.058108   -0.053216
# GSL_Yield_PAD      -0.321501    -0.086441   -0.370532   -0.322128   -0.307042
# DSL_Yield_PAD       0.500132     0.460969    0.555415    0.489277    0.479170
# RESID_Yield_PAD     0.685544     0.630231    0.703622    0.680780    0.677427
#
#                    COKING  FUELSOLDEASP  THERMCRCK  VACMDIST  Crude_API  \
# CATCRKRECYL      0.998532      0.994152   0.956268  0.993644  -0.067890
# CATHYDRCRCK      0.830037      0.865739   0.775157  0.866782  -0.287034
# CATHYDTRMT       0.967021      0.993466   0.987453  0.993924  -0.199882
# CATLREFORM       0.999454      0.992119   0.952709  0.991548  -0.058108
# CATLYTCRCK       0.999207      0.989661   0.943482  0.989050  -0.053216
# COKING           1.000000      0.988225   0.948729  0.987558  -0.042541
# FUELSOLDEASP     0.988225      1.000000   0.972987  0.999989  -0.138368
# THERMCRCK        0.948729      0.972987   1.000000  0.973440  -0.185338
# VACMDIST         0.987558      0.999989   0.973440  1.000000  -0.141415
# Crude_API       -0.042541     -0.138368  -0.185338 -0.141415   1.000000
# GSL_Yield_PAD   -0.328759     -0.333118  -0.460229 -0.333669   0.162330
# DSL_Yield_PAD    0.472887      0.533064   0.534469  0.533995   0.082101
# RESID_Yield_PAD  0.672647      0.700804   0.678498  0.701171  -0.257201
#
#                  GSL_Yield_PAD  DSL_Yield_PAD  RESID_Yield_PAD
# CATCRKRECYL          -0.321501       0.500132         0.685544
# CATHYDRCRCK          -0.086441       0.460969         0.630231
# CATHYDTRMT           -0.370532       0.555415         0.703622
# CATLREFORM           -0.322128       0.489277         0.680780
# CATLYTCRCK           -0.307042       0.479170         0.677427
# COKING               -0.328759       0.472887         0.672647
# FUELSOLDEASP         -0.333118       0.533064         0.700804
# THERMCRCK            -0.460229       0.534469         0.678498
# VACMDIST             -0.333669       0.533995         0.701171
# Crude_API             0.162330       0.082101        -0.257201
# GSL_Yield_PAD         1.000000      -0.072788         0.066083
# DSL_Yield_PAD        -0.072788       1.000000         0.487131
# RESID_Yield_PAD       0.066083       0.487131         1.000000

# %%
rfy_corr_mtrx1 = rfy_corr.corr()
f, ax = plt.subplots(figsize=(18,9))

hm = sns.heatmap(round(rfy_corr_mtrx1,2), annot=True, ax=ax, cmap="coolwarm", fmt='.2f', linewidth=.05)

f.subplots_adjust(top=0.93)
t = f.suptitle('Data Feature Correlation - Refinery Configuration and Light Petroleum Product Yields', fontsize=14)

# %%
# Re-run with fewver refinery configuration parameters - only keep those that show to have high impact in the yields
# Keep: 'CATHYDTRMT', 'COKING', and 'Crude_API' as explanatory variables for the yield values:
rfy_corr_mtrx2 = rfy_df.iloc[:, np.r_[9, 12, 16, 18:21]].corr()

f, ax = plt.subplots(figsize=(10,5))

hm = sns.heatmap(round(rfy_corr_mtrx2,2), annot=True, ax=ax, cmap="coolwarm", fmt='.2f', linewidth=.05)

f.subplots_adjust(top=0.93)
t = f.suptitle('Data Feature Correlation - Refinery Configuration and Light Petroleum Product Yields', fontsize=14)

# %%
# select refinery configuration parameters that seem to have clear impact on the yields distribution
rfy_yields_corr = rfy_df.iloc[:, np.r_[9, 12, 16, 18:21]]
rfy_yields_corr.tail()
# Out:
#      CATHYDTRMT   COKING  Crude_API  GSL_Yield_PAD  DSL_Yield_PAD  \
# 966       60200   220860  32.240000      46.790909      38.481818
# 967       60200   220860  32.240000      46.790909      38.481818
# 968       60200   220860  32.240000      46.790909      38.481818
# 969       60200   220860  32.240000      46.790909      38.481818
# 970      379700  1358935  26.115455      41.750000      50.880000
#
#      RESID_Yield_PAD
# 966         5.281818
# 967         5.281818
# 968         5.281818
# 969         5.281818
# 970         6.770000

# %%
sns.pairplot(rfy_yields_corr, palette='Set1')
plt.show()

# %% [markdown]
# # 3.5 Feature Engineering

# %% [markdown]
# ## 3.5.1 Merge refinery and markets features

# %%
# *TEMP*
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 76 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Series              971 non-null    object
#  1   RFY-PADD            971 non-null    object
#  2   RFY-PAD-Sub         971 non-null    object
#  3   RFY-PAD-District    971 non-null    object
#  4   RFY_ID              971 non-null    object
#  5   RFY_State           971 non-null    object
#  6   RFY_BPCD            971 non-null    int64
#  7   CATCRKRECYL         971 non-null    int64
#  8   CATHYDRCRCK         971 non-null    int64
#  9   CATHYDTRMT          971 non-null    int64
#  10  CATLREFORM          971 non-null    int64
#  11  CATLYTCRCK          971 non-null    int64
#  12  COKING              971 non-null    int64
#  13  FUELSOLDEASP        971 non-null    int64
#  14  THERMCRCK           971 non-null    int64
#  15  VACMDIST            971 non-null    int64
#  16  Crude_API           971 non-null    float64
#  17  NG_Yield_PAD        971 non-null    float64
#  18  GSL_Yield_PAD       971 non-null    float64
#  19  DSL_Yield_PAD       971 non-null    float64
#  20  RESID_Yield_PAD     971 non-null    float64
#  21  WTI_Price           971 non-null    float64
#  22  WTI_Diff            971 non-null    float64
#  23  WTI_Acq_Cost        971 non-null    float64
#  24  Brent_Price         971 non-null    float64
#  25  Brent_Diff          971 non-null    float64
#  26  CRCK_WTI_PAD-1A     971 non-null    float64
#  27  CRCK_WTI_PAD-1B     971 non-null    float64
#  28  CRCK_WTI_PAD-1C     971 non-null    float64
#  29  CRCK_WTI_PAD-2      971 non-null    float64
#  30  CRCK_WTI_PAD-3      971 non-null    float64
#  31  CRCK_WTI_PAD-4      971 non-null    float64
#  32  CRCK_WTI_PAD-5      971 non-null    float64
#  33  SPECF_CRCK_PAD-1A   971 non-null    float64
#  34  SPECF_CRCK_PAD-1B   971 non-null    float64
#  35  SPECF_CRCK_PAD-1C   971 non-null    float64
#  36  SPECF_CRCK_PAD-2    971 non-null    float64
#  37  SPECF_CRCK_PAD-3    971 non-null    float64
#  38  SPECF_CRCK_PAD-4    971 non-null    float64
#  39  SPECF_CRCK_PAD-5    971 non-null    float64
#  40  SPECF_RFY_CRCK      971 non-null    float64
#  41  Dist_PAD-1A         971 non-null    float64
#  42  Dist_PAD-1B         971 non-null    float64
#  43  Dist_PAD-1C         971 non-null    float64
#  44  Dist_PAD-2          971 non-null    float64
#  45  Dist_PAD-3          971 non-null    float64
#  46  Dist_PAD-4          971 non-null    float64
#  47  Dist_PAD-5          971 non-null    float64
#  48  RFY_Press_PAD-1A    971 non-null    float64
#  49  RFY_Press_PAD-1B    971 non-null    float64
#  50  RFY_Press_PAD-1C    971 non-null    float64
#  51  RFY_Press_PAD-2     971 non-null    float64
#  52  RFY_Press_PAD-3     971 non-null    float64
#  53  RFY_Press_PAD-4     971 non-null    float64
#  54  RFY_Press_PAD-5     971 non-null    float64
#  55  BPD_DENS_PAD-1A     971 non-null    float64
#  56  BPD_DENS_PAD-1B     971 non-null    float64
#  57  BPD_DENS_PAD-1C     971 non-null    float64
#  58  BPD_DENS_PAD-2      971 non-null    float64
#  59  BPD_DENS_PAD-3      971 non-null    float64
#  60  BPD_DENS_PAD-4      971 non-null    float64
#  61  BPD_DENS_PAD-5      971 non-null    float64
#  62  MRKT_RESIST_PAD-1A  971 non-null    float64
#  63  MRKT_RESIST_PAD-1B  971 non-null    float64
#  64  MRKT_RESIST_PAD-1C  971 non-null    float64
#  65  MRKT_RESIST_PAD-2   971 non-null    float64
#  66  MRKT_RESIST_PAD-3   971 non-null    float64
#  67  MRKT_RESIST_PAD-4   971 non-null    float64
#  68  MRKT_RESIST_PAD-5   971 non-null    float64
#  69  REVNUE_PAD-1A       971 non-null    float64
#  70  REVNUE_PAD-1B       971 non-null    float64
#  71  REVNUE_PAD-1C       971 non-null    float64
#  72  REVNUE_PAD-2        971 non-null    float64
#  73  REVNUE_PAD-3        971 non-null    float64
#  74  REVNUE_PAD-4        971 non-null    float64
#  75  REVNUE_PAD-5        971 non-null    float64
# dtypes: float64(60), int64(10), object(6)
# memory usage: 576.7+ KB

# %% [markdown]
# ### 3.5.1.1 Cleaned up Dataframe for Refinery Feature Values

# %%
# dataframe with finalized selection of feature variables for Refinery summary data
refinery_summary = data.iloc[:,np.r_[3:7, 9, 12, 16, 18:21, 23, 33:48]]
refinery_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   RFY-PAD-District   971 non-null    object
#  1   RFY_ID             971 non-null    object
#  2   RFY_State          971 non-null    object
#  3   RFY_BPCD           971 non-null    int64
#  4   CATHYDTRMT         971 non-null    int64
#  5   COKING             971 non-null    int64
#  6   Crude_API          971 non-null    float64
#  7   GSL_Yield_PAD      971 non-null    float64
#  8   DSL_Yield_PAD      971 non-null    float64
#  9   RESID_Yield_PAD    971 non-null    float64
#  10  WTI_Acq_Cost       971 non-null    float64
#  11  SPECF_CRCK_PAD-1A  971 non-null    float64
#  12  SPECF_CRCK_PAD-1B  971 non-null    float64
#  13  SPECF_CRCK_PAD-1C  971 non-null    float64
#  14  SPECF_CRCK_PAD-2   971 non-null    float64
#  15  SPECF_CRCK_PAD-3   971 non-null    float64
#  16  SPECF_CRCK_PAD-4   971 non-null    float64
#  17  SPECF_CRCK_PAD-5   971 non-null    float64
#  18  SPECF_RFY_CRCK     971 non-null    float64
#  19  Dist_PAD-1A        971 non-null    float64
#  20  Dist_PAD-1B        971 non-null    float64
#  21  Dist_PAD-1C        971 non-null    float64
#  22  Dist_PAD-2         971 non-null    float64
#  23  Dist_PAD-3         971 non-null    float64
#  24  Dist_PAD-4         971 non-null    float64
#  25  Dist_PAD-5         971 non-null    float64
# dtypes: float64(20), int64(3), object(3)
# memory usage: 197.4+ KB

# %% [markdown]
# ### 3.5.1.2 Cleaned up Dataframe for Market Feature Values

# %%
# dataframe with finalized selection of feature variables for Market summary data
markets_summary = data.iloc[:,np.r_[21, 55:76]]
markets_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WTI_Price           971 non-null    float64
#  1   BPD_DENS_PAD-1A     971 non-null    float64
#  2   BPD_DENS_PAD-1B     971 non-null    float64
#  3   BPD_DENS_PAD-1C     971 non-null    float64
#  4   BPD_DENS_PAD-2      971 non-null    float64
#  5   BPD_DENS_PAD-3      971 non-null    float64
#  6   BPD_DENS_PAD-4      971 non-null    float64
#  7   BPD_DENS_PAD-5      971 non-null    float64
#  8   MRKT_RESIST_PAD-1A  971 non-null    float64
#  9   MRKT_RESIST_PAD-1B  971 non-null    float64
#  10  MRKT_RESIST_PAD-1C  971 non-null    float64
#  11  MRKT_RESIST_PAD-2   971 non-null    float64
#  12  MRKT_RESIST_PAD-3   971 non-null    float64
#  13  MRKT_RESIST_PAD-4   971 non-null    float64
#  14  MRKT_RESIST_PAD-5   971 non-null    float64
#  15  REVNUE_PAD-1A       971 non-null    float64
#  16  REVNUE_PAD-1B       971 non-null    float64
#  17  REVNUE_PAD-1C       971 non-null    float64
#  18  REVNUE_PAD-2        971 non-null    float64
#  19  REVNUE_PAD-3        971 non-null    float64
#  20  REVNUE_PAD-4        971 non-null    float64
#  21  REVNUE_PAD-5        971 non-null    float64
# dtypes: float64(22)
# memory usage: 167.0 KB

# %% [markdown]
# ### 3.5.1.3 Merge into one dataframe

# %%
data_df = pd.merge(refinery_summary, markets_summary, left_index=True, right_index=True)

# %%
data_df = data_df.set_index('RFY_State')

# %%
data_df.head(3)
# Out:
#           RFY-PAD-District   RFY_ID  RFY_BPCD  CATHYDTRMT   COKING  Crude_API  \
# RFY_State
# Alabama            PAD-3-3  RFY-001     87500     1433000  3080090  30.170833
# Alabama            PAD-3-3  RFY-002     48000     1433000  3080090  30.170833
# Alabama            PAD-3-3  RFY-003      4100     1433000  3080090  30.170833
#
#            GSL_Yield_PAD  DSL_Yield_PAD  RESID_Yield_PAD  WTI_Acq_Cost  ...  \
# RFY_State                                                               ...
# Alabama           43.775      41.591667         9.083333    101.551667  ...
# Alabama           43.775      41.591667         9.083333    101.551667  ...
# Alabama           43.775      41.591667         9.083333    101.551667  ...
#
#            MRKT_RESIST_PAD-3  MRKT_RESIST_PAD-4  MRKT_RESIST_PAD-5  \
# RFY_State
# Alabama             0.137156           0.124693           0.160174
# Alabama             0.141351           0.125477           0.160625
# Alabama             0.138816           0.125594           0.160302
#
#            REVNUE_PAD-1A  REVNUE_PAD-1B  REVNUE_PAD-1C  REVNUE_PAD-2  \
# RFY_State
# Alabama        122.51066     128.188765     135.921938    159.764681
# Alabama        122.51066     128.188765     135.921938    159.764681
# Alabama        122.51066     128.188765     135.921938    159.764681
#
#            REVNUE_PAD-3  REVNUE_PAD-4  REVNUE_PAD-5
# RFY_State
# Alabama      170.104231     170.73112    176.232496
# Alabama      170.104231     170.73112    176.232496
# Alabama      170.104231     170.73112    176.232496
#
# [3 rows x 47 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 971 entries, Alabama to North Dakota
# Data columns (total 47 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RFY-PAD-District    971 non-null    object
#  1   RFY_ID              971 non-null    object
#  2   RFY_BPCD            971 non-null    int64
#  3   CATHYDTRMT          971 non-null    int64
#  4   COKING              971 non-null    int64
#  5   Crude_API           971 non-null    float64
#  6   GSL_Yield_PAD       971 non-null    float64
#  7   DSL_Yield_PAD       971 non-null    float64
#  8   RESID_Yield_PAD     971 non-null    float64
#  9   WTI_Acq_Cost        971 non-null    float64
#  10  SPECF_CRCK_PAD-1A   971 non-null    float64
#  11  SPECF_CRCK_PAD-1B   971 non-null    float64
#  12  SPECF_CRCK_PAD-1C   971 non-null    float64
#  13  SPECF_CRCK_PAD-2    971 non-null    float64
#  14  SPECF_CRCK_PAD-3    971 non-null    float64
#  15  SPECF_CRCK_PAD-4    971 non-null    float64
#  16  SPECF_CRCK_PAD-5    971 non-null    float64
#  17  SPECF_RFY_CRCK      971 non-null    float64
#  18  Dist_PAD-1A         971 non-null    float64
#  19  Dist_PAD-1B         971 non-null    float64
#  20  Dist_PAD-1C         971 non-null    float64
#  21  Dist_PAD-2          971 non-null    float64
#  22  Dist_PAD-3          971 non-null    float64
#  23  Dist_PAD-4          971 non-null    float64
#  24  Dist_PAD-5          971 non-null    float64
#  25  WTI_Price           971 non-null    float64
#  26  BPD_DENS_PAD-1A     971 non-null    float64
#  27  BPD_DENS_PAD-1B     971 non-null    float64
#  28  BPD_DENS_PAD-1C     971 non-null    float64
#  29  BPD_DENS_PAD-2      971 non-null    float64
#  30  BPD_DENS_PAD-3      971 non-null    float64
#  31  BPD_DENS_PAD-4      971 non-null    float64
#  32  BPD_DENS_PAD-5      971 non-null    float64
#  33  MRKT_RESIST_PAD-1A  971 non-null    float64
#  34  MRKT_RESIST_PAD-1B  971 non-null    float64
#  35  MRKT_RESIST_PAD-1C  971 non-null    float64
#  36  MRKT_RESIST_PAD-2   971 non-null    float64
#  37  MRKT_RESIST_PAD-3   971 non-null    float64
#  38  MRKT_RESIST_PAD-4   971 non-null    float64
#  39  MRKT_RESIST_PAD-5   971 non-null    float64
#  40  REVNUE_PAD-1A       971 non-null    float64
#  41  REVNUE_PAD-1B       971 non-null    float64
#  42  REVNUE_PAD-1C       971 non-null    float64
#  43  REVNUE_PAD-2        971 non-null    float64
#  44  REVNUE_PAD-3        971 non-null    float64
#  45  REVNUE_PAD-4        971 non-null    float64
#  46  REVNUE_PAD-5        971 non-null    float64
# dtypes: float64(42), int64(3), object(2)
# memory usage: 364.1+ KB

# %% [markdown]
# ### Select features for the correlation heatmap:

# %%
data_df_mtrx = data_df.iloc[:,np.r_[5:10, 25, 33:40, 10:18]]
data_df_mtrx.head(3).T
# Out:
# RFY_State              Alabama     Alabama     Alabama
# Crude_API            30.170833   30.170833   30.170833
# GSL_Yield_PAD        43.775000   43.775000   43.775000
# DSL_Yield_PAD        41.591667   41.591667   41.591667
# RESID_Yield_PAD       9.083333    9.083333    9.083333
# WTI_Acq_Cost        101.551667  101.551667  101.551667
# WTI_Price            97.905833   97.905833   97.905833
# MRKT_RESIST_PAD-1A    0.127066    0.125435    0.126055
# MRKT_RESIST_PAD-1B    0.150569    0.149195    0.150020
# MRKT_RESIST_PAD-1C    0.145237    0.144251    0.143978
# MRKT_RESIST_PAD-2     0.155105    0.153665    0.155235
# MRKT_RESIST_PAD-3     0.137156    0.141351    0.138816
# MRKT_RESIST_PAD-4     0.124693    0.125477    0.125594
# MRKT_RESIST_PAD-5     0.160174    0.160625    0.160302
# SPECF_CRCK_PAD-1A     2.663174    2.628996    2.641989
# SPECF_CRCK_PAD-1B     4.010721    3.974120    3.996095
# SPECF_CRCK_PAD-1C     4.991846    4.957959    4.948553
# SPECF_CRCK_PAD-2      9.029151    8.945316    9.036713
# SPECF_CRCK_PAD-3      9.402363    9.689983    9.516189
# SPECF_CRCK_PAD-4      8.626171    8.680436    8.688529
# SPECF_CRCK_PAD-5     11.961942   11.995611   11.971487
# SPECF_RFY_CRCK       50.685368   50.872421   50.799553

# %% [markdown]
# ### 3.5.1 Feature Correlation Heatmap

# %%
f, ax = plt.subplots(figsize=(20,20))

hm = sns.heatmap(round(data_df_mtrx.corr(),2), annot=True, ax=ax, cmap="coolwarm", fmt='.2f', linewidth=.05)

f.subplots_adjust(top=0.93)
t = f.suptitle('Data Feature Correlation - Refinery and Markets', fontsize=14)

# %% [markdown]
# ### 3.5.2 Scatterplots

# %% [markdown]
# ### Select features for the paired scatterplots:

# %%
data_df_scatter = data_df.iloc[:,np.r_[0:2, 5:18, 25, 33:47]]

# %%
data_df_scatter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 971 entries, Alabama to North Dakota
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RFY-PAD-District    971 non-null    object
#  1   RFY_ID              971 non-null    object
#  2   Crude_API           971 non-null    float64
#  3   GSL_Yield_PAD       971 non-null    float64
#  4   DSL_Yield_PAD       971 non-null    float64
#  5   RESID_Yield_PAD     971 non-null    float64
#  6   WTI_Acq_Cost        971 non-null    float64
#  7   SPECF_CRCK_PAD-1A   971 non-null    float64
#  8   SPECF_CRCK_PAD-1B   971 non-null    float64
#  9   SPECF_CRCK_PAD-1C   971 non-null    float64
#  10  SPECF_CRCK_PAD-2    971 non-null    float64
#  11  SPECF_CRCK_PAD-3    971 non-null    float64
#  12  SPECF_CRCK_PAD-4    971 non-null    float64
#  13  SPECF_CRCK_PAD-5    971 non-null    float64
#  14  SPECF_RFY_CRCK      971 non-null    float64
#  15  WTI_Price           971 non-null    float64
#  16  MRKT_RESIST_PAD-1A  971 non-null    float64
#  17  MRKT_RESIST_PAD-1B  971 non-null    float64
#  18  MRKT_RESIST_PAD-1C  971 non-null    float64
#  19  MRKT_RESIST_PAD-2   971 non-null    float64
#  20  MRKT_RESIST_PAD-3   971 non-null    float64
#  21  MRKT_RESIST_PAD-4   971 non-null    float64
#  22  MRKT_RESIST_PAD-5   971 non-null    float64
#  23  REVNUE_PAD-1A       971 non-null    float64
#  24  REVNUE_PAD-1B       971 non-null    float64
#  25  REVNUE_PAD-1C       971 non-null    float64
#  26  REVNUE_PAD-2        971 non-null    float64
#  27  REVNUE_PAD-3        971 non-null    float64
#  28  REVNUE_PAD-4        971 non-null    float64
#  29  REVNUE_PAD-5        971 non-null    float64
# dtypes: float64(28), object(2)
# memory usage: 235.2+ KB

# %%
# define useful function to create scatterplots of ticket prices against desired columns
def scatterplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=0.6)
    
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x = col, y = 'SPECF_RFY_CRCK', data=data_df_scatter, alpha=0.5)
        ax.set(xlabel=col, ylabel='Specf Ref Crack')
    nsubplots = nrow * ncol    
    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
#Use a list comprehension to build a list of features from the columns of `data_df_scatter` that
#are _not_ any of 'RFY-PAD-District', 'RFY_ID', or 'SPECF_RFY_CRCK'

# ignore_array = ['RFY-PAD-District', 'RFY_ID', 'SPECF_RFY_CRCK', ]

features = [i for i in data_df_scatter.columns if i not in ['RFY-PAD-District', 'RFY_ID', 'SPECF_RFY_CRCK']]

# %%
scatterplots(features, ncol=4, figsize=(15, 20))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# # 3.6 Summary
